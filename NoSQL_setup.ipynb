# %% [markdown]
# # Eat Safe, Love

# %% [markdown]
# ## Part 1: Database and Jupyter Notebook Set Up

# %% [markdown]
# Import the data provided in the `establishments.json` file from your Terminal. Name the database `uk_food` and the collection `establishments`.
#
# Within this markdown cell, copy the line of text you used to import the data from your Terminal. This way, future analysts will be able to repeat your process.
#
# e.g.: Import the dataset with `mongoimport --type json -d uk_food -c establishments --drop --jsonArray establishments.json`

# %%
# Import dependencies
from pymongo import MongoClient
from pprint import pprint
from decimal import Decimal

# %%
# Create an instance of MongoClient
mongo = MongoClient(port=27017)

# %%
# confirm that our new database was created
print(mongo.list_database_names())
# Out:
# ['admin', 'autosaurus', 'classDB', 'config', 'fruits_db', 'local', 'uk_food']

# %%
# assign the uk_food database to a variable name
db = mongo['uk_food']

# %%
# review the collections in our new database
print(db.list_collection_names())
# Out:
# ['establishments']

# %%
# review a document in the establishments collection
pprint(db.establishments.find_one())
# Out:
# {'AddressLine1': 'The Pines Garden',
#  'AddressLine2': 'Beach Road',
#  'AddressLine3': 'St Margarets Bay',
#  'AddressLine4': 'Kent',
#  'BusinessName': 'The Pines Calyx',
#  'BusinessType': 'Other catering premises',
#  'BusinessTypeID': 7841,
#  'ChangesByServerID': 0,
#  'Distance': 4587.362402580997,
#  'FHRSID': 254250,
#  'LocalAuthorityBusinessID': 'PI/000066174',
#  'LocalAuthorityCode': '182',
#  'LocalAuthorityEmailAddress': 'publicprotection@dover.gov.uk',
#  'LocalAuthorityName': 'Dover',
#  'LocalAuthorityWebSite': 'http://www.dover.gov.uk/',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'CT15 6DZ',
#  'RatingDate': '2021-08-17T00:00:00',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingValue': '5',
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('669ca9e954452054d92ab370'),
#  'geocode': {'latitude': '51.148133', 'longitude': '1.383298'},
#  'links': [{'href': 'https://api.ratings.food.gov.uk/establishments/254250',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 0, 'Hygiene': 0, 'Structural': 0}}

# %%
# assign the collection to a variable
establishments = db['establishments']

# %% [markdown]
# ## Part 2: Update the Database

# %% [markdown]
# 1. An exciting new halal restaurant just opened in Greenwich, but hasn't been rated yet. The magazine has asked you to include it in your analysis. Add the following restaurant "Penang Flavours" to the database.

# %%
# Create a dictionary for the new restaurant data
new_restaurant = {
    "BusinessName":"Penang Flavours",
    "BusinessType":"Restaurant/Cafe/Canteen",
    "BusinessTypeID":"",
    "AddressLine1":"Penang Flavours",
    "AddressLine2":"146A Plumstead Rd",
    "AddressLine3":"London",
    "AddressLine4":"",
    "PostCode":"SE18 7DY",
    "Phone":"",
    "LocalAuthorityCode":"511",
    "LocalAuthorityName":"Greenwich",
    "LocalAuthorityWebSite":"http://www.royalgreenwich.gov.uk",
    "LocalAuthorityEmailAddress":"health@royalgreenwich.gov.uk",
    "scores":{
        "Hygiene":"",
        "Structural":"",
        "ConfidenceInManagement":""
    },
    "SchemeType":"FHRS",
    "geocode":{
        "longitude":"0.08384000",
        "latitude":"51.49014200"
    },
    "RightToReply":"",
    "Distance":4623.9723280747176,
    "NewRatingPending":True
}

# %%
# Insert the new restaurant into the collection
establishments.insert_one(new_restaurant)
# Out:
# InsertOneResult(ObjectId('669ca9f6b8bce198c5a8c2a1'), acknowledged=True)

# %%
# Check that the new restaurant was inserted
query = {'BusinessName': 'Penang Flavours'}
results = establishments.find(query)
for result in results:
    pprint(result)
# Out:
# {'AddressLine1': 'Penang Flavours',
#  'AddressLine2': '146A Plumstead Rd',
#  'AddressLine3': 'London',
#  'AddressLine4': '',
#  'BusinessName': 'Penang Flavours',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': '',
#  'Distance': 4623.972328074718,
#  'LocalAuthorityCode': '511',
#  'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#  'LocalAuthorityName': 'Greenwich',
#  'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#  'NewRatingPending': True,
#  'Phone': '',
#  'PostCode': 'SE18 7DY',
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('669ca9f6b8bce198c5a8c2a1'),
#  'geocode': {'latitude': '51.49014200', 'longitude': '0.08384000'},
#  'scores': {'ConfidenceInManagement': '', 'Hygiene': '', 'Structural': ''}}

# %% [markdown]
# 2. Find the BusinessTypeID for "Restaurant/Cafe/Canteen" and return only the `BusinessTypeID` and `BusinessType` fields.

# %%
# Find the BusinessTypeID for "Restaurant/Cafe/Canteen" and return only the BusinessTypeID and BusinessType fields
query = {'BusinessType': 'Restaurant/Cafe/Canteen'}
fields = {'BusinessTypeID': 1, 'BusinessType': 1}  # Include only desired fields

results = establishments.find(query, fields)

for result in results:
    pprint(result)
# Out:
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab372')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab373')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab374')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab375')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab377')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab379')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab37d')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab37f')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab380')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab381')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab382')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab383')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab38d')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab390')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab395')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab39e')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab3a0')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab3a2')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab3a4')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab3a6')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab3a7')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab3aa')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab3ad')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab3b0')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab3b1')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab3b2')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab3b3')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab3b7')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab3bc')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab3be')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab3c1')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab3c3')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab3c4')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab3c8')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab3c9')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab3ca')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab3d5')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab3d7')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab3dd')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab3de')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab3e0')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab3e1')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab3e3')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab3e4')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab3e9')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab3f2')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab3f3')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab3f6')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab3f8')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab3f9')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab3fa')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab3fc')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab3fd')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab405')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab40c')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab40d')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab411')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab41a')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab41b')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab41e')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab41f')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab420')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab421')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab42b')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab42c')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab431')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab437')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab439')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab43a')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab43f')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab441')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab447')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab449')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab44f')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab45c')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab45d')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab45f')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab460')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab469')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab46e')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab46f')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab470')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab474')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab480')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab483')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab48c')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab48e')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab490')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab497')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab498')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab49d')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab4a4')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab4a8')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab4a9')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab4ac')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab4ad')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab4b2')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab4b4')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab4b6')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab4b9')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab4ba')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab4bc')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab4bd')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab4be')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab4c1')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab4c2')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab4c3')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab4c6')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab4ca')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab4cd')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab4d4')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab4d6')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab4db')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab4dc')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab4df')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab4e7')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab4e8')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab4e9')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab4ea')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab4ec')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab4f0')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab4f4')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab4f6')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab4f7')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab4f8')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab505')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab508')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab509')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab50c')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab510')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab512')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab518')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab51b')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab51c')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab526')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab527')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab52a')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab531')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab533')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab534')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab537')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab53a')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab542')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab543')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab549')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab555')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab560')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab56b')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab58c')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab591')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab595')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab596')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab598')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab5a7')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab5ab')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab5bf')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab5d8')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab5dc')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab5e5')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab5ea')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab5ed')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab5fa')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab5fc')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab608')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab609')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab60e')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab611')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab613')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab615')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab61c')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab61e')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab621')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab625')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab626')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab62b')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab636')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab637')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab639')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab649')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab64c')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab64d')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab652')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab656')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab663')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab665')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab66a')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab66b')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab678')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab67f')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab682')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab687')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab688')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab68a')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab68c')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab69b')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab6a0')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab6a4')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab6ac')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab6ae')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab6af')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab6b2')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab6b5')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab6b7')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab6ba')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab6bb')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab6bc')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab6bd')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab6c4')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab6c6')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab6c7')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab6cd')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab6ce')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab6d1')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab6d5')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab6d6')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab6d7')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab6dd')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab6de')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab6e1')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab6e6')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab6e9')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab6eb')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab6ec')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab6f0')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab6f2')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab6f4')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab6fa')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab6fb')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab6fd')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab6fe')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab702')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab703')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab705')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab709')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab70f')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab711')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab714')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab719')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab71b')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab71e')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab720')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab727')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab728')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab729')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab72c')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab732')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab733')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab735')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab73b')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab73d')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab73f')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab740')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab741')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab744')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab746')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab748')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab74a')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab74b')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab74e')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab75b')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab75d')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab75f')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab762')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab764')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab769')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab76a')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab76b')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab76d')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab76f')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab771')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab772')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab778')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab77b')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab77d')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab781')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab78f')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab795')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab7a7')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab7a9')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab7ab')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab7b1')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab7b2')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab7c1')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab7ca')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab7ce')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab7d3')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab7d6')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab7d8')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab7d9')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab7dd')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab7e9')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab7eb')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab7ec')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab7ee')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab7ef')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab7f1')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab7f2')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab7f3')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab7f4')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab7f5')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab7f6')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab7fe')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab7ff')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab804')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab807')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab80b')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab80d')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab80e')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab80f')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab810')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab814')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab816')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab818')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab81a')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab81e')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab822')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab823')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab828')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab829')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab82a')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab82b')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab82c')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab82d')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab830')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab832')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab833')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab842')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab843')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab844')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab846')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab848')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab84a')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab853')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab855')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab85c')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab85d')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab863')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab864')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab867')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab868')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab86b')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab873')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab879')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab87d')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab889')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab88d')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab88e')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab890')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab891')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab892')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab89c')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab89d')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab89e')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab8a0')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab8a2')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab8a5')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab8a9')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab8b1')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab8b2')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab8b7')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab8bd')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab8bf')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab8c1')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab8c3')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab8c6')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab8c7')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab8c9')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab8ca')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab8cc')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab8cd')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab8cf')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab8d0')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab8d1')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab8d3')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab8d4')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab8d8')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab8d9')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab8da')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab8dc')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab8dd')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab8de')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab8df')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab8e0')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab8e2')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab8e3')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab8e4')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab8e6')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab8e7')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab8ea')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab8ed')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab8ee')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab8f6')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab8f7')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab8f8')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab8f9')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab8fa')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab8ff')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab906')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab908')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab909')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab90d')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab90e')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab912')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab915')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab91b')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab91e')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab929')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab936')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab93d')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab940')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab943')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab945')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab94e')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab952')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab958')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab959')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab95e')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab960')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab963')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab964')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab965')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab96a')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab96d')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab970')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab97d')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab97f')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab982')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9e954452054d92ab985')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
# ...
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9eb54452054d92b4cbf')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9eb54452054d92b4cc0')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9eb54452054d92b4cc1')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9eb54452054d92b4cc2')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9eb54452054d92b4cc3')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9eb54452054d92b4cc7')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9eb54452054d92b4cc9')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9eb54452054d92b4ccc')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9eb54452054d92b4ccd')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9eb54452054d92b4ccf')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9eb54452054d92b4cd6')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9eb54452054d92b4cdf')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9eb54452054d92b4ce0')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9eb54452054d92b4ce3')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9eb54452054d92b4ce7')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9eb54452054d92b4ce8')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9eb54452054d92b4ce9')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9eb54452054d92b4cea')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9eb54452054d92b4ceb')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9eb54452054d92b4cec')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9eb54452054d92b4cee')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9eb54452054d92b4cef')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9eb54452054d92b4cf3')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9eb54452054d92b4cf4')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9eb54452054d92b4cf5')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9eb54452054d92b4cf6')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9eb54452054d92b4cf7')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9eb54452054d92b4cfa')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9eb54452054d92b4cfb')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9eb54452054d92b4cfc')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9eb54452054d92b4d00')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9eb54452054d92b4d05')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9eb54452054d92b4d0b')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9eb54452054d92b4d0c')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9eb54452054d92b4d0d')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9eb54452054d92b4d0e')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9eb54452054d92b4d10')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9eb54452054d92b4d11')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9eb54452054d92b4d16')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9eb54452054d92b4d17')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9eb54452054d92b4d20')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9eb54452054d92b4d22')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9eb54452054d92b4d24')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9eb54452054d92b4d28')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9eb54452054d92b4d2b')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9eb54452054d92b4d31')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9eb54452054d92b4d37')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9eb54452054d92b4d38')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9eb54452054d92b4d3e')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9eb54452054d92b4d44')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9eb54452054d92b4d63')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9eb54452054d92b4d6d')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9eb54452054d92b4d73')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9eb54452054d92b4d75')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9eb54452054d92b4d76')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9eb54452054d92b4d79')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9eb54452054d92b4d7b')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9eb54452054d92b4d7d')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9eb54452054d92b4d7e')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9eb54452054d92b4d7f')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9eb54452054d92b4d80')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9eb54452054d92b4d81')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9eb54452054d92b4d93')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9eb54452054d92b4da0')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9eb54452054d92b4da3')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9eb54452054d92b4da8')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9eb54452054d92b4dac')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9eb54452054d92b4dad')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9eb54452054d92b4db4')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9eb54452054d92b4db6')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9eb54452054d92b4dba')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9eb54452054d92b4dbf')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9eb54452054d92b4dc1')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9eb54452054d92b4dc4')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9eb54452054d92b4dc8')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9eb54452054d92b4dc9')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9eb54452054d92b4dca')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9eb54452054d92b4dcf')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9eb54452054d92b4de4')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9eb54452054d92b4de6')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9eb54452054d92b4dee')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9eb54452054d92b4df0')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9eb54452054d92b4df8')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9eb54452054d92b4dfd')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9eb54452054d92b4dfe')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9eb54452054d92b4e02')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9eb54452054d92b4e04')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9eb54452054d92b4e0e')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9eb54452054d92b4e0f')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9eb54452054d92b4e10')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9eb54452054d92b4e18')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9eb54452054d92b4e1d')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9eb54452054d92b4e20')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9eb54452054d92b4e23')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9eb54452054d92b4e24')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9eb54452054d92b4e26')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9eb54452054d92b4e29')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9eb54452054d92b4e2a')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9eb54452054d92b4e2c')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9eb54452054d92b4e2d')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9eb54452054d92b4e30')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9eb54452054d92b4e31')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9eb54452054d92b4e32')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9eb54452054d92b4e33')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9eb54452054d92b4e39')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9eb54452054d92b4e3a')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9eb54452054d92b4e3b')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9eb54452054d92b4e3c')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9eb54452054d92b4e3d')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9eb54452054d92b4e40')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9eb54452054d92b4e41')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9eb54452054d92b4e42')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9eb54452054d92b4e43')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9eb54452054d92b4e47')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9eb54452054d92b4e4b')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9eb54452054d92b4e4d')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9eb54452054d92b4e4f')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9eb54452054d92b4e53')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9eb54452054d92b4e54')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9eb54452054d92b4e58')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9eb54452054d92b4e5d')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9eb54452054d92b4e61')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9eb54452054d92b4e65')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9eb54452054d92b4e6e')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9eb54452054d92b4e70')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9eb54452054d92b4e76')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9eb54452054d92b4e79')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9eb54452054d92b4e7b')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9eb54452054d92b4e7d')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9eb54452054d92b4e7f')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9eb54452054d92b4e8d')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9eb54452054d92b4e97')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9eb54452054d92b4e98')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9eb54452054d92b4eac')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9eb54452054d92b4eb0')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9eb54452054d92b4eb2')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9eb54452054d92b4eb8')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9eb54452054d92b4eba')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9eb54452054d92b4ebd')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9eb54452054d92b4ec1')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9eb54452054d92b4ec3')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('669ca9eb54452054d92b4ed0')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': '',
#  '_id': ObjectId('669ca9f6b8bce198c5a8c2a1')}

# %% [markdown]
# 3. Update the new restaurant with the `BusinessTypeID` you found.

# %%
# Update the new restaurant with the correct BusinessTypeID
query = {'BusinessName': 'Penang Flavours'}
update = {"$set": {"BusinessTypeID": 1}}

result = establishments.update_one(query, update)

# %%
# Confirm that the new restaurant was updated
query = {'BusinessName': 'Penang Flavours'}
results = establishments.find(query)
for result in results:
    pprint(result)
# Out:
# {'AddressLine1': 'Penang Flavours',
#  'AddressLine2': '146A Plumstead Rd',
#  'AddressLine3': 'London',
#  'AddressLine4': '',
#  'BusinessName': 'Penang Flavours',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  'Distance': 4623.972328074718,
#  'LocalAuthorityCode': '511',
#  'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#  'LocalAuthorityName': 'Greenwich',
#  'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#  'NewRatingPending': True,
#  'Phone': '',
#  'PostCode': 'SE18 7DY',
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('669ca9f6b8bce198c5a8c2a1'),
#  'geocode': {'latitude': '51.49014200', 'longitude': '0.08384000'},
#  'scores': {'ConfidenceInManagement': '', 'Hygiene': '', 'Structural': ''}}

# %% [markdown]
# 4. The magazine is not interested in any establishments in Dover, so check how many documents contain the Dover Local Authority. Then, remove any establishments within the Dover Local Authority from the database, and check the number of documents to ensure they were deleted.

# %%
# Find how many documents have LocalAuthorityName as "Dover"
count = establishments.count_documents({'LocalAuthorityName': 'Dover'})

print(f"Number of documents that have LocalAuthorityName 'Dover': {count}")
# Out:
# Number of documents that have LocalAuthorityName 'Dover': 994

# %%
# Delete all documents where LocalAuthorityName is "Dover"
query = {'LocalAuthorityName': 'Dover'}
results = establishments.delete_many(query)

# %%
# Check if any remaining documents include Dover
query = {'LocalAuthorityName': 'Dover'}
count = establishments.count_documents(query)

if count > 0:
    results = establishments.find(query)
    for result in results:
        print(result)
else:
    print("No documents found for LocalAuthorityName 'Dover'")
# Out:
# No documents found for LocalAuthorityName 'Dover'

# %%
# Check that other documents remain with 'find_one'
query = {"LocalAuthorityName": {"$ne": "Dover"}} # Query all LocalAuthorityName not equal to "Dover"
fields = {"BusinessName": 1, "LocalAuthorityName": 1, "_id": 0}

result = establishments.find_one(query, fields)

print(result)
# Out:
# {'BusinessName': 'The Pavilion', 'LocalAuthorityName': 'Folkestone and Hythe'}

# %% [markdown]
# 5. Some of the number values are stored as strings, when they should be stored as numbers.

# %% [markdown]
# Use `update_many` to convert `latitude` and `longitude` to decimal numbers.

# %%
# Change the data type from String to Decimal for longitude and latitude
establishments.update_many({}, [
    {'$set': {
        'geocode.latitude': {'$toDouble': '$geocode.latitude'},
        'geocode.longitude': {'$toDouble': '$geocode.longitude'}
    }}
])
# Out:
# UpdateResult({'n': 38786, 'nModified': 38786, 'ok': 1.0, 'updatedExisting': True}, acknowledged=True)

# %% [markdown]
# Use `update_many` to convert `RatingValue` to integer numbers.

# %%
# Set non 1-5 Rating Values to Null
non_ratings = ["AwaitingInspection", "Awaiting Inspection", "AwaitingPublication", "Pass", "Exempt"]
establishments.update_many({"RatingValue": {"$in": non_ratings}}, [ {'$set':{ "RatingValue" : None}} ])
# Out:
# UpdateResult({'n': 4091, 'nModified': 4091, 'ok': 1.0, 'updatedExisting': True}, acknowledged=True)

# %%
# Change the data type from String to Integer for RatingValue
establishments.update_many({}, [
    {'$set': {
        'RatingValue': {'$toInt': '$RatingValue'}
    }}
])
# Out:
# UpdateResult({'n': 38786, 'nModified': 34695, 'ok': 1.0, 'updatedExisting': True}, acknowledged=True)

# %%
# Check that the coordinates and rating value are now numbers
# Retrieve a sample document from the collection
sample_document = establishments.find_one()

# Loop through the fields in the sample document to check their data types
for field, value in sample_document.items():
    data_type = type(value).__name__
    print(f"{field}: {data_type}")
# Out:
# _id: ObjectId
# FHRSID: int
# ChangesByServerID: int
# LocalAuthorityBusinessID: str
# BusinessName: str
# BusinessType: str
# BusinessTypeID: int
# AddressLine1: str
# AddressLine2: str
# AddressLine3: str
# AddressLine4: str
# PostCode: str
# Phone: str
# RatingValue: int
# RatingKey: str
# RatingDate: str
# LocalAuthorityCode: str
# LocalAuthorityName: str
# LocalAuthorityWebSite: str
# LocalAuthorityEmailAddress: str
# scores: dict
# SchemeType: str
# geocode: dict
# RightToReply: str
# Distance: float
# NewRatingPending: bool
# meta: dict
# links: list

# %%
# Check that the coordinates and rating value are now numbers
query = {"BusinessType": "Restaurant/Cafe/Canteen"}
fields = {"BusinessName": 1, "geocode.latitude": 1, "geocode.longitude": 1, "RatingValue": 1}  # Include only desired fields

results = establishments.find(query, fields)

for result in results:
   pprint(result)
# Out:
# {'BusinessName': 'The Pavilion',
#  'RatingValue': 5,
#  '_id': ObjectId('669ca9e954452054d92ab656'),
#  'geocode': {'latitude': 51.083812, 'longitude': 1.195625}}
# {'BusinessName': 'Dr Legumes - Harbour Arm',
#  'RatingValue': 4,
#  '_id': ObjectId('669ca9e954452054d92ab663'),
#  'geocode': {'latitude': 51.0783519967076, 'longitude': 1.18590330311705}}
# {'BusinessName': 'Custom Folkestone',
#  'RatingValue': 5,
#  '_id': ObjectId('669ca9e954452054d92ab665'),
#  'geocode': {'latitude': 51.0783519967076, 'longitude': 1.18590330311705}}
# {'BusinessName': "Dino's",
#  'RatingValue': 4,
#  '_id': ObjectId('669ca9e954452054d92ab66a'),
#  'geocode': {'latitude': 51.0783519967076, 'longitude': 1.18590330311705}}
# {'BusinessName': 'Barney & The Pizza',
#  'RatingValue': 3,
#  '_id': ObjectId('669ca9e954452054d92ab66b'),
#  'geocode': {'latitude': 51.0783519967076, 'longitude': 1.18590330311705}}
# {'BusinessName': 'Harbour Coffee Company',
#  'RatingValue': 5,
#  '_id': ObjectId('669ca9e954452054d92ab678'),
#  'geocode': {'latitude': 51.0783519967076, 'longitude': 1.18590330311705}}
# {'BusinessName': 'Putters!',
#  'RatingValue': None,
#  '_id': ObjectId('669ca9e954452054d92ab67f'),
#  'geocode': {'latitude': 51.0783519967076, 'longitude': 1.18590330311705}}
# {'BusinessName': 'The Lighthouse Tasting Rooms',
#  'RatingValue': 5,
#  '_id': ObjectId('669ca9e954452054d92ab682'),
#  'geocode': {'latitude': 51.0783519967076, 'longitude': 1.18590330311705}}
# {'BusinessName': 'Little Switzerland Cafe',
#  'RatingValue': 5,
#  '_id': ObjectId('669ca9e954452054d92ab687'),
#  'geocode': {'latitude': 51.095015, 'longitude': 1.202055}}
# {'BusinessName': 'The Captains Table',
#  'RatingValue': 5,
#  '_id': ObjectId('669ca9e954452054d92ab688'),
#  'geocode': {'latitude': 51.080673, 'longitude': 1.187083}}
# {'BusinessName': 'Herberts',
#  'RatingValue': 5,
#  '_id': ObjectId('669ca9e954452054d92ab68a'),
#  'geocode': {'latitude': 51.080284, 'longitude': 1.186485}}
# {'BusinessName': 'Rocksalt',
#  'RatingValue': 5,
#  '_id': ObjectId('669ca9e954452054d92ab68c'),
#  'geocode': {'latitude': 51.080284, 'longitude': 1.186485}}
# {'BusinessName': 'Pick Up Pintxos',
#  'RatingValue': 5,
#  '_id': ObjectId('669ca9e954452054d92ab69b'),
#  'geocode': {'latitude': 51.0803, 'longitude': 1.184916}}
# {'BusinessName': 'Folklore',
#  'RatingValue': 5,
#  '_id': ObjectId('669ca9e954452054d92ab6a0'),
#  'geocode': {'latitude': 51.0804748535156, 'longitude': 1.18425798416138}}
# {'BusinessName': 'Bella Vita',
#  'RatingValue': 5,
#  '_id': ObjectId('669ca9e954452054d92ab6a4'),
#  'geocode': {'latitude': 51.0804824829102, 'longitude': 1.18421399593353}}
# {'BusinessName': 'Diamond Cafe',
#  'RatingValue': 5,
#  '_id': ObjectId('669ca9e954452054d92ab6ac'),
#  'geocode': {'latitude': 51.080956, 'longitude': 1.18429}}
# {'BusinessName': 'Touchbase Care',
#  'RatingValue': 5,
#  '_id': ObjectId('669ca9e954452054d92ab6ae'),
#  'geocode': {'latitude': 51.080804, 'longitude': 1.183893}}
# {'BusinessName': 'The Nook',
#  'RatingValue': 4,
#  '_id': ObjectId('669ca9e954452054d92ab6af'),
#  'geocode': {'latitude': 51.080805, 'longitude': 1.183894}}
# {'BusinessName': 'El Cortador',
#  'RatingValue': 5,
#  '_id': ObjectId('669ca9e954452054d92ab6b2'),
#  'geocode': {'latitude': 51.08034, 'longitude': 1.182805}}
# {'BusinessName': 'Steep Street Coffee House',
#  'RatingValue': 5,
#  '_id': ObjectId('669ca9e954452054d92ab6b5'),
#  'geocode': {'latitude': 51.080339, 'longitude': 1.182805}}
# {'BusinessName': 'Big Boys Fine Burger Co',
#  'RatingValue': 5,
#  '_id': ObjectId('669ca9e954452054d92ab6b7'),
#  'geocode': {'latitude': 51.08034, 'longitude': 1.182805}}
# {'BusinessName': 'Hillside Restaurant',
#  'RatingValue': 4,
#  '_id': ObjectId('669ca9e954452054d92ab6ba'),
#  'geocode': {'latitude': 51.079889, 'longitude': 1.181832}}
# {'BusinessName': 'Misused Cocktails',
#  'RatingValue': 5,
#  '_id': ObjectId('669ca9e954452054d92ab6bb'),
#  'geocode': {'latitude': 51.0802956, 'longitude': 1.1823865}}
# {'BusinessName': 'The Space Bar & Gallery',
#  'RatingValue': 3,
#  '_id': ObjectId('669ca9e954452054d92ab6bc'),
#  'geocode': {'latitude': 51.0803409, 'longitude': 1.1822069}}
# {'BusinessName': 'Lucky Chip',
#  'RatingValue': 5,
#  '_id': ObjectId('669ca9e954452054d92ab6bd'),
#  'geocode': {'latitude': 51.079532623291, 'longitude': 1.1813759803772}}
# {'BusinessName': 'Planet Earth Kitchen',
#  'RatingValue': 5,
#  '_id': ObjectId('669ca9e954452054d92ab6c4'),
#  'geocode': {'latitude': 51.079799, 'longitude': 1.181482}}
# {'BusinessName': 'Sweet Rendezvous',
#  'RatingValue': 5,
#  '_id': ObjectId('669ca9e954452054d92ab6c6'),
#  'geocode': {'latitude': 51.0800235, 'longitude': 1.1813097}}
# {'BusinessName': 'Aspendos Restaurant',
#  'RatingValue': 3,
#  '_id': ObjectId('669ca9e954452054d92ab6c7'),
#  'geocode': {'latitude': 51.078209, 'longitude': 1.179446}}
# {'BusinessName': 'Lubens',
#  'RatingValue': 5,
#  '_id': ObjectId('669ca9e954452054d92ab6cd'),
#  'geocode': {'latitude': 51.080675, 'longitude': 1.181728}}
# {'BusinessName': 'Eleto Chocolate Cafe',
#  'RatingValue': 3,
#  '_id': ObjectId('669ca9e954452054d92ab6ce'),
#  'geocode': {'latitude': 51.0806732177734, 'longitude': 1.18172800540924}}
# {'BusinessName': 'The Tearooms',
#  'RatingValue': 5,
#  '_id': ObjectId('669ca9e954452054d92ab6d1'),
#  'geocode': {'latitude': 51.0793698, 'longitude': 1.1802781}}
# {'BusinessName': 'Wonderland Tearoom',
#  'RatingValue': 5,
#  '_id': ObjectId('669ca9e954452054d92ab6d5'),
#  'geocode': {'latitude': 51.080675, 'longitude': 1.181728}}
# {'BusinessName': 'Oriental Buffet',
#  'RatingValue': 3,
#  '_id': ObjectId('669ca9e954452054d92ab6d6'),
#  'geocode': {'latitude': 51.080675, 'longitude': 1.181728}}
# {'BusinessName': 'Androus Cafe',
#  'RatingValue': 5,
#  '_id': ObjectId('669ca9e954452054d92ab6d7'),
#  'geocode': {'latitude': 51.08164, 'longitude': 1.182609}}
# {'BusinessName': 'Curry Garden',
#  'RatingValue': 4,
#  '_id': ObjectId('669ca9e954452054d92ab6dd'),
#  'geocode': {'latitude': 51.0818634033203, 'longitude': 1.18279695510864}}
# {'BusinessName': 'Djangos',
#  'RatingValue': 5,
#  '_id': ObjectId('669ca9e954452054d92ab6de'),
#  'geocode': {'latitude': 51.080417, 'longitude': 1.181282}}
# {'BusinessName': 'Market Square Folkestone',
#  'RatingValue': 5,
#  '_id': ObjectId('669ca9e954452054d92ab6e1'),
#  'geocode': {'latitude': 51.0804176330566, 'longitude': 1.18128204345703}}
# {'BusinessName': 'Luciano Pizzaria',
#  'RatingValue': 5,
#  '_id': ObjectId('669ca9e954452054d92ab6e6'),
#  'geocode': {'latitude': 51.08187, 'longitude': 1.182753}}
# {'BusinessName': 'Cube Cafe',
#  'RatingValue': 5,
#  '_id': ObjectId('669ca9e954452054d92ab6e9'),
#  'geocode': {'latitude': 51.081494, 'longitude': 1.182356}}
# {'BusinessName': 'Kathmandu House Grilled Tandoori',
#  'RatingValue': 4,
#  '_id': ObjectId('669ca9e954452054d92ab6eb'),
#  'geocode': {'latitude': 51.078296, 'longitude': 1.178909}}
# {'BusinessName': 'Mcdonalds Restaurant',
#  'RatingValue': 5,
#  '_id': ObjectId('669ca9e954452054d92ab6ec'),
#  'geocode': {'latitude': 51.078296, 'longitude': 1.178909}}
# {'BusinessName': 'Sunshine Coffee and Restaurant',
#  'RatingValue': 3,
#  '_id': ObjectId('669ca9e954452054d92ab6f0'),
#  'geocode': {'latitude': 51.0785865783691, 'longitude': 1.17911505699158}}
# {'BusinessName': 'Fireaway Pizza Folkestone',
#  'RatingValue': 5,
#  '_id': ObjectId('669ca9e954452054d92ab6f2'),
#  'geocode': {'latitude': 51.078117, 'longitude': 1.1784815}}
# {'BusinessName': "Grind n' Bake",
#  'RatingValue': 5,
#  '_id': ObjectId('669ca9e954452054d92ab6f4'),
#  'geocode': {'latitude': 51.079632, 'longitude': 1.179729}}
# {'BusinessName': 'Zen Cafe Asian Diner',
#  'RatingValue': 5,
#  '_id': ObjectId('669ca9e954452054d92ab6fa'),
#  'geocode': {'latitude': 51.080315, 'longitude': 1.18039}}
# {'BusinessName': 'Lilys American Diner',
#  'RatingValue': 4,
#  '_id': ObjectId('669ca9e954452054d92ab6fb'),
#  'geocode': {'latitude': 51.078131, 'longitude': 1.178027}}
# {'BusinessName': 'Abercrombies Community Kitchen',
#  'RatingValue': 5,
#  '_id': ObjectId('669ca9e954452054d92ab6fd'),
#  'geocode': {'latitude': 51.0818613, 'longitude': 1.1818685}}
# {'BusinessName': 'RESTOCK',
#  'RatingValue': 5,
#  '_id': ObjectId('669ca9e954452054d92ab6fe'),
#  'geocode': {'latitude': 51.0802287, 'longitude': 1.1806797}}
# {'BusinessName': 'La Princesse',
#  'RatingValue': 3,
#  '_id': ObjectId('669ca9e954452054d92ab702'),
#  'geocode': {'latitude': 51.0781968, 'longitude': 1.1783613}}
# {'BusinessName': 'The Bao Baron',
#  'RatingValue': 5,
#  '_id': ObjectId('669ca9e954452054d92ab703'),
#  'geocode': {'latitude': 51.080211, 'longitude': 1.179926}}
# {'BusinessName': 'Costa Coffee',
#  'RatingValue': 5,
#  '_id': ObjectId('669ca9e954452054d92ab705'),
#  'geocode': {'latitude': 51.079161, 'longitude': 1.17884}}
# {'BusinessName': 'Caffe La Delizia',
#  'RatingValue': 5,
#  '_id': ObjectId('669ca9e954452054d92ab709'),
#  'geocode': {'latitude': 51.079482, 'longitude': 1.178962}}
# {'BusinessName': 'EK Baar',
#  'RatingValue': 5,
#  '_id': ObjectId('669ca9e954452054d92ab70f'),
#  'geocode': {'latitude': 51.0783433, 'longitude': 1.1776046}}
# {'BusinessName': 'Folkestone 51',
#  'RatingValue': None,
#  '_id': ObjectId('669ca9e954452054d92ab711'),
#  'geocode': {'latitude': 51.0824157, 'longitude': 1.1817418}}
# {'BusinessName': 'KFC',
#  'RatingValue': 5,
#  '_id': ObjectId('669ca9e954452054d92ab714'),
#  'geocode': {'latitude': 51.078317, 'longitude': 1.177468}}
# {'BusinessName': 'Starbucks',
#  'RatingValue': 5,
#  '_id': ObjectId('669ca9e954452054d92ab719'),
#  'geocode': {'latitude': 51.079482, 'longitude': 1.178962}}
# {'BusinessName': 'Blank Canvas Cafe Ltd',
#  'RatingValue': 5,
#  '_id': ObjectId('669ca9e954452054d92ab71b'),
#  'geocode': {'latitude': 51.080668, 'longitude': 1.179628}}
# {'BusinessName': 'The Full English',
#  'RatingValue': 5,
#  '_id': ObjectId('669ca9e954452054d92ab71e'),
#  'geocode': {'latitude': 51.080669, 'longitude': 1.179629}}
# {'BusinessName': 'Bettys Pye & Mash',
#  'RatingValue': 2,
#  '_id': ObjectId('669ca9e954452054d92ab720'),
#  'geocode': {'latitude': 51.0804496, 'longitude': 1.1794011}}
# {'BusinessName': 'Burger King',
#  'RatingValue': 5,
#  '_id': ObjectId('669ca9e954452054d92ab727'),
#  'geocode': {'latitude': 51.079081, 'longitude': 1.177506}}
# {'BusinessName': 'Cafe Tulip',
#  'RatingValue': 4,
#  '_id': ObjectId('669ca9e954452054d92ab728'),
#  'geocode': {'latitude': 51.080624, 'longitude': 1.178969}}
# {'BusinessName': 'Asda Cafe',
#  'RatingValue': 5,
#  '_id': ObjectId('669ca9e954452054d92ab729'),
#  'geocode': {'latitude': 51.079679, 'longitude': 1.17799}}
# {'BusinessName': 'Le Cafe Ganmac',
#  'RatingValue': 5,
#  '_id': ObjectId('669ca9e954452054d92ab72c'),
#  'geocode': {'latitude': 51.077626, 'longitude': 1.17575}}
# {'BusinessName': 'Roccos',
#  'RatingValue': 3,
#  '_id': ObjectId('669ca9e954452054d92ab732'),
#  'geocode': {'latitude': 51.077626, 'longitude': 1.17575}}
# {'BusinessName': 'Leas Cliff Hall',
#  'RatingValue': 5,
#  '_id': ObjectId('669ca9e954452054d92ab733'),
#  'geocode': {'latitude': 51.0758056640625, 'longitude': 1.17352676391602}}
# {'BusinessName': 'Thong-Dees',
#  'RatingValue': 3,
#  '_id': ObjectId('669ca9e954452054d92ab735'),
#  'geocode': {'latitude': 51.077626, 'longitude': 1.17575}}
# {'BusinessName': 'The Little Place......Next Door',
#  'RatingValue': 5,
#  '_id': ObjectId('669ca9e954452054d92ab73b'),
#  'geocode': {'latitude': 51.07879, 'longitude': 1.176258}}
# {'BusinessName': 'Laurielles Cafe',
#  'RatingValue': 5,
#  '_id': ObjectId('669ca9e954452054d92ab73d'),
#  'geocode': {'latitude': 51.078513, 'longitude': 1.175897}}
# {'BusinessName': 'Bella Pizza & Pasta',
#  'RatingValue': 4,
#  '_id': ObjectId('669ca9e954452054d92ab73f'),
#  'geocode': {'latitude': 51.078033, 'longitude': 1.17535}}
# {'BusinessName': 'Browns Coffee House',
#  'RatingValue': 4,
#  '_id': ObjectId('669ca9e954452054d92ab740'),
#  'geocode': {'latitude': 51.078033, 'longitude': 1.17535}}
# {'BusinessName': 'Papas',
#  'RatingValue': 5,
#  '_id': ObjectId('669ca9e954452054d92ab741'),
#  'geocode': {'latitude': 51.078033, 'longitude': 1.17535}}
# {'BusinessName': 'Gourmet Kitchen',
#  'RatingValue': 5,
#  '_id': ObjectId('669ca9e954452054d92ab744'),
#  'geocode': {'latitude': 51.078033, 'longitude': 1.17535}}
# {'BusinessName': 'Waves Coffee House',
#  'RatingValue': 5,
#  '_id': ObjectId('669ca9e954452054d92ab746'),
#  'geocode': {'latitude': 51.078515, 'longitude': 1.175811}}
# {'BusinessName': 'Annapurna',
#  'RatingValue': 5,
#  '_id': ObjectId('669ca9e954452054d92ab748'),
#  'geocode': {'latitude': 51.07873, 'longitude': 1.17584}}
# {'BusinessName': "Anna's Tearoom",
#  'RatingValue': 5,
#  '_id': ObjectId('669ca9e954452054d92ab74a'),
#  'geocode': {'latitude': 51.07873, 'longitude': 1.17584}}
# {'BusinessName': 'Food For Thought',
#  'RatingValue': 3,
#  '_id': ObjectId('669ca9e954452054d92ab74b'),
#  'geocode': {'latitude': 51.07873, 'longitude': 1.17584}}
# {'BusinessName': 'Three Hills Sports Park',
#  'RatingValue': 5,
#  '_id': ObjectId('669ca9e954452054d92ab74e'),
#  'geocode': {'latitude': 51.0806630002457, 'longitude': 1.17725700019713}}
# {'BusinessName': 'Genesis',
#  'RatingValue': 5,
#  '_id': ObjectId('669ca9e954452054d92ab75b'),
#  'geocode': {'latitude': 51.077492, 'longitude': 1.173056}}
# {'BusinessName': 'Sotirios Bar & Restaurant',
#  'RatingValue': 4,
#  '_id': ObjectId('669ca9e954452054d92ab75d'),
#  'geocode': {'latitude': 51.079039, 'longitude': 1.174748}}
# {'BusinessName': 'The Brasserie MS',
#  'RatingValue': None,
#  '_id': ObjectId('669ca9e954452054d92ab75f'),
#  'geocode': {'latitude': 51.076577, 'longitude': 1.17198}}
# {'BusinessName': 'The Brasserie MS',
#  'RatingValue': None,
#  '_id': ObjectId('669ca9e954452054d92ab762'),
#  'geocode': {'latitude': 51.076577, 'longitude': 1.17198}}
# {'BusinessName': 'Rosemont Restaurant & Cocktail Bar',
#  'RatingValue': 5,
#  '_id': ObjectId('669ca9e954452054d92ab764'),
#  'geocode': {'latitude': 51.077414, 'longitude': 1.172652}}
# {'BusinessName': 'Swiss Reassurance Ltd',
#  'RatingValue': 5,
#  '_id': ObjectId('669ca9e954452054d92ab769'),
#  'geocode': {'latitude': 51.077702, 'longitude': 1.172314}}
# {'BusinessName': 'The Waterfront Cafe Bar',
#  'RatingValue': 4,
#  '_id': ObjectId('669ca9e954452054d92ab76b'),
#  'geocode': {'latitude': 51.074167, 'longitude': 1.16866}}
# {'BusinessName': 'Bouverie Tap',
#  'RatingValue': 5,
#  '_id': ObjectId('669ca9e954452054d92ab76d'),
#  'geocode': {'latitude': 51.078197, 'longitude': 1.172619}}
# {'BusinessName': 'Ali Baba Grill',
#  'RatingValue': 3,
#  '_id': ObjectId('669ca9e954452054d92ab76f'),
#  'geocode': {'latitude': 51.078197, 'longitude': 1.172619}}
# {'BusinessName': 'The Hideaway',
#  'RatingValue': 4,
#  '_id': ObjectId('669ca9e954452054d92ab771'),
#  'geocode': {'latitude': 51.078197, 'longitude': 1.172619}}
# {'BusinessName': 'Conchitas',
#  'RatingValue': 5,
#  '_id': ObjectId('669ca9e954452054d92ab772'),
#  'geocode': {'latitude': 51.078197, 'longitude': 1.172619}}
# {'BusinessName': 'The Radnor Arms',
#  'RatingValue': 5,
#  '_id': ObjectId('669ca9e954452054d92ab778'),
#  'geocode': {'latitude': 51.078885, 'longitude': 1.172452}}
# {'BusinessName': 'The View Hotel',
#  'RatingValue': 5,
#  '_id': ObjectId('669ca9e954452054d92ab77b'),
#  'geocode': {'latitude': 51.07623, 'longitude': 1.169515}}
# {'BusinessName': 'Cocomee',
#  'RatingValue': 5,
#  '_id': ObjectId('669ca9e954452054d92ab77d'),
#  'geocode': {'latitude': 51.078874, 'longitude': 1.171552}}
# {'BusinessName': 'Brew',
#  'RatingValue': 4,
#  '_id': ObjectId('669ca9e954452054d92ab781'),
#  'geocode': {'latitude': 51.08129, 'longitude': 1.17363}}
# {'BusinessName': 'Black Bull Cafe',
#  'RatingValue': 5,
#  '_id': ObjectId('669ca9e954452054d92ab795'),
#  'geocode': {'latitude': 51.087034, 'longitude': 1.178766}}
# {'BusinessName': 'Bridge Coffee House',
#  'RatingValue': 1,
#  '_id': ObjectId('669ca9e954452054d92ab7a7'),
#  'geocode': {'latitude': 51.082374, 'longitude': 1.171506}}
# {'BusinessName': 'Grand Hotel',
#  'RatingValue': 5,
#  '_id': ObjectId('669ca9e954452054d92ab7a9'),
#  'geocode': {'latitude': 51.0751419067383, 'longitude': 1.16350066661835}}
# {'BusinessName': 'Radnor Park Lodge',
#  'RatingValue': 5,
#  '_id': ObjectId('669ca9e954452054d92ab7ab'),
#  'geocode': {'latitude': 51.083812713623, 'longitude': 1.17163395881653}}
# {'BusinessName': 'League of Friends Coffee Shop',
#  'RatingValue': 5,
#  '_id': ObjectId('669ca9e954452054d92ab7b1'),
#  'geocode': {'latitude': 51.085755, 'longitude': 1.172865}}
# {'BusinessName': 'Wards Hotel & Bistro',
#  'RatingValue': 4,
#  '_id': ObjectId('669ca9e954452054d92ab7b2'),
#  'geocode': {'latitude': 51.078911, 'longitude': 1.165543}}
# {'BusinessName': 'Tunnels Tea Shop',
#  'RatingValue': 5,
#  '_id': ObjectId('669ca9e954452054d92ab7ce'),
#  'geocode': {'latitude': 51.3344841003418, 'longitude': 1.42664802074432}}
# {'BusinessName': 'Sorbetto',
#  'RatingValue': 5,
#  '_id': ObjectId('669ca9e954452054d92ab7d6'),
#  'geocode': {'latitude': 51.33222, 'longitude': 1.423192}}
# {'BusinessName': 'A La Turka',
#  'RatingValue': 5,
#  '_id': ObjectId('669ca9e954452054d92ab7d8'),
#  'geocode': {'latitude': 51.33222, 'longitude': 1.423192}}
# {'BusinessName': 'Alexandra Restaurant',
#  'RatingValue': 5,
#  '_id': ObjectId('669ca9e954452054d92ab7d9'),
#  'geocode': {'latitude': 51.332221, 'longitude': 1.423192}}
# {'BusinessName': 'The Dog House & Grill',
#  'RatingValue': 5,
#  '_id': ObjectId('669ca9e954452054d92ab7dd'),
#  'geocode': {'latitude': 51.332221, 'longitude': 1.423192}}
# {'BusinessName': 'Thai Passion',
#  'RatingValue': 4,
#  '_id': ObjectId('669ca9e954452054d92ab7e9'),
#  'geocode': {'latitude': 51.3322219848633, 'longitude': 1.42319202423096}}
# {'BusinessName': 'Alison Sea View Cafe',
#  'RatingValue': 5,
#  '_id': ObjectId('669ca9e954452054d92ab7eb'),
#  'geocode': {'latitude': 51.3351135253906, 'longitude': 1.42612195014954}}
# {'BusinessName': 'Folkestone Sports Centre',
#  'RatingValue': 5,
#  '_id': ObjectId('669ca9e954452054d92ab7ec'),
#  'geocode': {'latitude': 51.087041, 'longitude': 1.168241}}
# {'BusinessName': "Sam's Bar",
#  'RatingValue': 5,
#  '_id': ObjectId('669ca9e954452054d92ab7ee'),
#  'geocode': {'latitude': 51.349914, 'longitude': 1.440672}}
# {'BusinessName': 'Clique Bar',
#  'RatingValue': 5,
#  '_id': ObjectId('669ca9e954452054d92ab7f1'),
#  'geocode': {'latitude': 51.332386, 'longitude': 1.421525}}
# {'BusinessName': 'Little Ships',
#  'RatingValue': 5,
#  '_id': ObjectId('669ca9e954452054d92ab7f2'),
#  'geocode': {'latitude': 51.332386, 'longitude': 1.421525}}
# {'BusinessName': 'Thanet Bowling Club',
#  'RatingValue': 5,
#  '_id': ObjectId('669ca9e954452054d92ab7f3'),
#  'geocode': {'latitude': 51.343133, 'longitude': 1.432365}}
# {'BusinessName': 'The Glass House Tea Garden',
#  'RatingValue': 5,
#  '_id': ObjectId('669ca9e954452054d92ab7f4'),
#  'geocode': {'latitude': 51.343133, 'longitude': 1.432364}}
# {'BusinessName': 'Travellers in Italy',
#  'RatingValue': 5,
#  '_id': ObjectId('669ca9e954452054d92ab7f5'),
#  'geocode': {'latitude': 51.332495, 'longitude': 1.421188}}
# {'BusinessName': 'Enoteca',
#  'RatingValue': 5,
#  '_id': ObjectId('669ca9e954452054d92ab7f6'),
#  'geocode': {'latitude': 51.332386, 'longitude': 1.421525}}
# {'BusinessName': 'Baker Street Cafe',
#  'RatingValue': 5,
#  '_id': ObjectId('669ca9e954452054d92ab7fe'),
#  'geocode': {'latitude': 51.33875, 'longitude': 1.427211}}
# {'BusinessName': 'Royal Harbour Ramsgate Brasserie',
#  'RatingValue': 5,
#  '_id': ObjectId('669ca9e954452054d92ab7ff'),
#  'geocode': {'latitude': 51.331022, 'longitude': 1.421136}}
# {'BusinessName': 'Jah Jah',
#  'RatingValue': 5,
#  '_id': ObjectId('669ca9e954452054d92ab807'),
#  'geocode': {'latitude': 51.33308, 'longitude': 1.42027}}
# {'BusinessName': "Gerry's Coffee & Art House",
#  'RatingValue': 5,
#  '_id': ObjectId('669ca9e954452054d92ab80b'),
#  'geocode': {'latitude': 51.332515, 'longitude': 1.419581}}
# {'BusinessName': "Coco Latino & Clarey's Chocolates",
#  'RatingValue': 5,
#  '_id': ObjectId('669ca9e954452054d92ab80d'),
#  'geocode': {'latitude': 51.330413, 'longitude': 1.417328}}
# {'BusinessName': 'The Arch',
#  'RatingValue': 5,
#  '_id': ObjectId('669ca9e954452054d92ab80e'),
#  'geocode': {'latitude': 51.330413, 'longitude': 1.417328}}
# {'BusinessName': 'Ship Shape',
#  'RatingValue': 5,
#  '_id': ObjectId('669ca9e954452054d92ab80f'),
#  'geocode': {'latitude': 51.330413, 'longitude': 1.417328}}
# {'BusinessName': 'The Greek Arch',
#  'RatingValue': 5,
#  '_id': ObjectId('669ca9e954452054d92ab810'),
#  'geocode': {'latitude': 51.330413, 'longitude': 1.417328}}
# {'BusinessName': 'Archive Homestore',
#  'RatingValue': 5,
#  '_id': ObjectId('669ca9e954452054d92ab814'),
#  'geocode': {'latitude': 51.3310761, 'longitude': 1.4179475}}
# {'BusinessName': 'Ramsgate Tandoori',
#  'RatingValue': 5,
#  '_id': ObjectId('669ca9e954452054d92ab816'),
#  'geocode': {'latitude': 51.333009, 'longitude': 1.419934}}
# {'BusinessName': 'T.L.C',
#  'RatingValue': 5,
#  '_id': ObjectId('669ca9e954452054d92ab818'),
#  'geocode': {'latitude': 51.333009, 'longitude': 1.419934}}
# {'BusinessName': 'Book Bodega',
#  'RatingValue': 5,
#  '_id': ObjectId('669ca9e954452054d92ab81a'),
#  'geocode': {'latitude': 51.333152, 'longitude': 1.4198331}}
# {'BusinessName': 'Sunrise Cafe Restaurant',
#  'RatingValue': 5,
#  '_id': ObjectId('669ca9e954452054d92ab81e'),
#  'geocode': {'latitude': 51.332812, 'longitude': 1.419273}}
# {'BusinessName': 'Corbys Tearooms',
#  'RatingValue': 5,
#  '_id': ObjectId('669ca9e954452054d92ab822'),
#  'geocode': {'latitude': 51.332812, 'longitude': 1.419273}}
# {'BusinessName': 'Il Tricolore',
#  'RatingValue': 5,
#  '_id': ObjectId('669ca9e954452054d92ab823'),
#  'geocode': {'latitude': 51.333009, 'longitude': 1.419934}}
# {'BusinessName': 'Village Grill',
#  'RatingValue': 5,
#  '_id': ObjectId('669ca9e954452054d92ab828'),
#  'geocode': {'latitude': 51.333009, 'longitude': 1.419934}}
# {'BusinessName': 'The Galley',
#  'RatingValue': 5,
#  '_id': ObjectId('669ca9e954452054d92ab829'),
#  'geocode': {'latitude': 51.331827, 'longitude': 1.418209}}
# {'BusinessName': 'The Home Front Tea Room',
#  'RatingValue': 5,
#  '_id': ObjectId('669ca9e954452054d92ab82a'),
#  'geocode': {'latitude': 51.3338775634766, 'longitude': 1.42038595676422}}
# {'BusinessName': 'Marc-Pierres Kitchen',
#  'RatingValue': 5,
#  '_id': ObjectId('669ca9e954452054d92ab82b'),
#  'geocode': {'latitude': 51.331827, 'longitude': 1.418209}}
# {'BusinessName': 'LA. Magnolia Ice Cream & Deli',
#  'RatingValue': 5,
#  '_id': ObjectId('669ca9e954452054d92ab82c'),
#  'geocode': {'latitude': 51.331827, 'longitude': 1.418209}}
# {'BusinessName': 'Thai Orchid',
#  'RatingValue': 5,
#  '_id': ObjectId('669ca9e954452054d92ab82d'),
#  'geocode': {'latitude': 51.331827, 'longitude': 1.418209}}
# {'BusinessName': 'La Magnolia',
#  'RatingValue': 5,
#  '_id': ObjectId('669ca9e954452054d92ab830'),
#  'geocode': {'latitude': 51.331827, 'longitude': 1.418209}}
# {'BusinessName': 'Queens Marvellous Creations & TGB',
#  'RatingValue': 1,
#  '_id': ObjectId('669ca9e954452054d92ab832'),
#  'geocode': {'latitude': 51.3348208, 'longitude': 1.4212417}}
# {'BusinessName': 'Curio Collectors Emporium',
#  'RatingValue': 5,
#  '_id': ObjectId('669ca9e954452054d92ab833'),
#  'geocode': {'latitude': 51.3348734, 'longitude': 1.4212887}}
# {'BusinessName': 'Hearth Restaurant',
#  'RatingValue': 5,
#  '_id': ObjectId('669ca9e954452054d92ab842'),
#  'geocode': {'latitude': 51.330249, 'longitude': 1.416168}}
# {'BusinessName': 'The Lookout',
#  'RatingValue': 4,
#  '_id': ObjectId('669ca9e954452054d92ab843'),
#  'geocode': {'latitude': 51.330249, 'longitude': 1.416168}}
# {'BusinessName': 'KFC - Ramsgate',
#  'RatingValue': 5,
#  '_id': ObjectId('669ca9e954452054d92ab844'),
#  'geocode': {'latitude': 51.333159, 'longitude': 1.419098}}
# {'BusinessName': 'C and K Rileys Ltd',
#  'RatingValue': 5,
#  '_id': ObjectId('669ca9e954452054d92ab846'),
#  'geocode': {'latitude': 51.333159, 'longitude': 1.419098}}
# {'BusinessName': 'Zest Cafe & Bar',
#  'RatingValue': 5,
#  '_id': ObjectId('669ca9e954452054d92ab848'),
#  'geocode': {'latitude': 51.333159, 'longitude': 1.419098}}
# {'BusinessName': 'Dirtee Feast',
#  'RatingValue': 5,
#  '_id': ObjectId('669ca9e954452054d92ab84a'),
#  'geocode': {'latitude': 51.33542, 'longitude': 1.421435}}
# {'BusinessName': 'Souvlike - eat',
#  'RatingValue': 5,
#  '_id': ObjectId('669ca9e954452054d92ab853'),
#  'geocode': {'latitude': 51.334698, 'longitude': 1.42062}}
# {'BusinessName': 'Star Nergis',
#  'RatingValue': 5,
#  '_id': ObjectId('669ca9e954452054d92ab855'),
#  'geocode': {'latitude': 51.33407, 'longitude': 1.419941}}
# {'BusinessName': 'Sage Cafe Ramsgate',
#  'RatingValue': 5,
#  '_id': ObjectId('669ca9e954452054d92ab85c'),
#  'geocode': {'latitude': 51.334333, 'longitude': 1.419875}}
# {'BusinessName': "Seaside's Restaurant",
#  'RatingValue': 5,
#  '_id': ObjectId('669ca9e954452054d92ab85d'),
#  'geocode': {'latitude': 51.32935, 'longitude': 1.414923}}
# {'BusinessName': 'Caffe Nero',
#  'RatingValue': 4,
#  '_id': ObjectId('669ca9e954452054d92ab863'),
#  'geocode': {'latitude': 51.333723, 'longitude': 1.419183}}
# {'BusinessName': 'Ho Wong',
#  'RatingValue': 5,
#  '_id': ObjectId('669ca9e954452054d92ab864'),
#  'geocode': {'latitude': 51.33733, 'longitude': 1.42287}}
# {'BusinessName': 'Union Ramsgate',
#  'RatingValue': 5,
#  '_id': ObjectId('669ca9e954452054d92ab867'),
#  'geocode': {'latitude': 51.3332361, 'longitude': 1.4185246}}
# {'BusinessName': 'The Sun Club',
#  'RatingValue': 5,
#  '_id': ObjectId('669ca9e954452054d92ab868'),
#  'geocode': {'latitude': 51.3332361, 'longitude': 1.4185246}}
# {'BusinessName': 'Louisa Bay Cafe',
#  'RatingValue': 5,
#  '_id': ObjectId('669ca9e954452054d92ab86b'),
#  'geocode': {'latitude': 51.355251, 'longitude': 1.441503}}
# {'BusinessName': 'Coffee Hut',
#  'RatingValue': 5,
#  '_id': ObjectId('669ca9e954452054d92ab873'),
#  'geocode': {'latitude': 51.329475, 'longitude': 1.414028}}
# {'BusinessName': 'Kids Brighthouse',
#  'RatingValue': 5,
#  '_id': ObjectId('669ca9e954452054d92ab879'),
#  'geocode': {'latitude': 51.3343705, 'longitude': 1.4187957}}
# {'BusinessName': "Dee's Cafe",
#  'RatingValue': 5,
#  '_id': ObjectId('669ca9e954452054d92ab87d'),
#  'geocode': {'latitude': 51.3341827392578, 'longitude': 1.41851198673248}}
# {'BusinessName': 'Panorama Restaurant',
#  'RatingValue': 5,
#  '_id': ObjectId('669ca9e954452054d92ab889'),
#  'geocode': {'latitude': 51.331953, 'longitude': 1.415734}}
# {'BusinessName': 'Jetty Broadstairs',
#  'RatingValue': 5,
#  '_id': ObjectId('669ca9e954452054d92ab88d'),
#  'geocode': {'latitude': 51.359287, 'longitude': 1.44465}}
# {'BusinessName': 'Tartar Frigate',
#  'RatingValue': 5,
#  '_id': ObjectId('669ca9e954452054d92ab88e'),
#  'geocode': {'latitude': 51.359287, 'longitude': 1.444651}}
# {'BusinessName': 'Lillyputt Mini Golf',
#  'RatingValue': 5,
#  '_id': ObjectId('669ca9e954452054d92ab890'),
#  'geocode': {'latitude': 51.35668, 'longitude': 1.441553}}
# {'BusinessName': 'Wyatt and Jones',
#  'RatingValue': 5,
#  '_id': ObjectId('669ca9e954452054d92ab891'),
#  'geocode': {'latitude': 51.359287, 'longitude': 1.444651}}
# {'BusinessName': 'The Funicular Coffeehouse',
#  'RatingValue': 5,
#  '_id': ObjectId('669ca9e954452054d92ab892'),
#  'geocode': {'latitude': 51.3593597412109, 'longitude': 1.44435501098633}}
# {'BusinessName': 'Saga Pavilion Restaurant',
#  'RatingValue': 5,
#  '_id': ObjectId('669ca9e954452054d92ab89c'),
#  'geocode': {'latitude': 51.075712, 'longitude': 1.149104}}
# {'BusinessName': 'Flavours By Kumar',
#  'RatingValue': 5,
#  '_id': ObjectId('669ca9e954452054d92ab89d'),
#  'geocode': {'latitude': 51.33351, 'longitude': 1.416941}}
# {'BusinessName': 'Chiappinis Coffee Shop',
#  'RatingValue': 5,
#  '_id': ObjectId('669ca9e954452054d92ab89e'),
#  'geocode': {'latitude': 51.358305, 'longitude': 1.44258}}
# {'BusinessName': 'Kebbells',
#  'RatingValue': 5,
#  '_id': ObjectId('669ca9e954452054d92ab8a0'),
#  'geocode': {'latitude': 51.357652, 'longitude': 1.441842}}
# {'BusinessName': 'Bandstand Kiosk',
#  'RatingValue': 5,
#  '_id': ObjectId('669ca9e954452054d92ab8a2'),
#  'geocode': {'latitude': 51.357652, 'longitude': 1.441842}}
# {'BusinessName': 'Morellis Cappuchino Bars',
#  'RatingValue': 3,
#  '_id': ObjectId('669ca9e954452054d92ab8a5'),
#  'geocode': {'latitude': 51.357652, 'longitude': 1.441841}}
# {'BusinessName': 'Cafe Loki',
#  'RatingValue': 4,
#  '_id': ObjectId('669ca9e954452054d92ab8a9'),
#  'geocode': {'latitude': 51.359357, 'longitude': 1.443492}}
# {'BusinessName': 'Artfuls',
#  'RatingValue': 5,
#  '_id': ObjectId('669ca9e954452054d92ab8b1'),
#  'geocode': {'latitude': 51.358001, 'longitude': 1.441911}}
# {'BusinessName': 'The Old Curiosity Shop',
#  'RatingValue': 5,
#  '_id': ObjectId('669ca9e954452054d92ab8b2'),
#  'geocode': {'latitude': 51.359725, 'longitude': 1.443836}}
# {'BusinessName': 'Sandgate Vaults',
#  'RatingValue': 5,
#  '_id': ObjectId('669ca9e954452054d92ab8b7'),
#  'geocode': {'latitude': 51.07368, 'longitude': 1.14641}}
# {'BusinessName': 'Happily Ever Afters',
#  'RatingValue': 5,
#  '_id': ObjectId('669ca9e954452054d92ab8bd'),
#  'geocode': {'latitude': 51.3348463, 'longitude': 1.417444}}
# {'BusinessName': "Eats 'n' Beats",
#  'RatingValue': 5,
#  '_id': ObjectId('669ca9e954452054d92ab8bf'),
#  'geocode': {'latitude': 51.331538, 'longitude': 1.413923}}
# {'BusinessName': 'The Hive Cafe',
#  'RatingValue': 5,
#  '_id': ObjectId('669ca9e954452054d92ab8c1'),
#  'geocode': {'latitude': 51.33456, 'longitude': 1.41702}}
# {'BusinessName': 'Loaf',
#  'RatingValue': 5,
#  '_id': ObjectId('669ca9e954452054d92ab8c3'),
#  'geocode': {'latitude': 51.073679, 'longitude': 1.14641}}
# {'BusinessName': 'Costa Coffee',
#  'RatingValue': 5,
#  '_id': ObjectId('669ca9e954452054d92ab8c6'),
#  'geocode': {'latitude': 51.358316, 'longitude': 1.441891}}
# {'BusinessName': 'The Table',
#  'RatingValue': 5,
#  '_id': ObjectId('669ca9e954452054d92ab8c7'),
#  'geocode': {'latitude': 51.3577308, 'longitude': 1.44121}}
# {'BusinessName': 'DOS',
#  'RatingValue': 5,
#  '_id': ObjectId('669ca9e954452054d92ab8c9'),
#  'geocode': {'latitude': 51.356834, 'longitude': 1.4403}}
# {'BusinessName': "St George's Community Meal",
#  'RatingValue': 5,
#  '_id': ObjectId('669ca9e954452054d92ab8ca'),
#  'geocode': {'latitude': 51.3355637, 'longitude': 1.4179799}}
# {'BusinessName': 'La Zia Maria',
#  'RatingValue': 5,
#  '_id': ObjectId('669ca9e954452054d92ab8cc'),
#  'geocode': {'latitude': 51.357734, 'longitude': 1.441186}}
# {'BusinessName': 'Tilucks II',
#  'RatingValue': 3,
#  '_id': ObjectId('669ca9e954452054d92ab8cd'),
#  'geocode': {'latitude': 51.073919, 'longitude': 1.146198}}
# {'BusinessName': 'Forts',
#  'RatingValue': 5,
#  '_id': ObjectId('669ca9e954452054d92ab8cf'),
#  'geocode': {'latitude': 51.3576863, 'longitude': 1.4411923}}
# {'BusinessName': 'Be Me Tea Limited',
#  'RatingValue': 5,
#  '_id': ObjectId('669ca9e954452054d92ab8d0'),
#  'geocode': {'latitude': 51.358155, 'longitude': 1.441563}}
# {'BusinessName': 'New China Inn',
#  'RatingValue': 5,
#  '_id': ObjectId('669ca9e954452054d92ab8d1'),
#  'geocode': {'latitude': 51.358155, 'longitude': 1.441563}}
# {'BusinessName': "Veg'N Out",
#  'RatingValue': 5,
#  '_id': ObjectId('669ca9e954452054d92ab8d3'),
#  'geocode': {'latitude': 51.359586, 'longitude': 1.44305}}
# {'BusinessName': 'Siam Kitchen',
#  'RatingValue': 5,
#  '_id': ObjectId('669ca9e954452054d92ab8d4'),
#  'geocode': {'latitude': 51.359586, 'longitude': 1.44305}}
# {'BusinessName': 'Aqua 43',
#  'RatingValue': 5,
#  '_id': ObjectId('669ca9e954452054d92ab8d8'),
#  'geocode': {'latitude': 51.359586, 'longitude': 1.44305}}
# {'BusinessName': "Seggari's",
#  'RatingValue': 5,
#  '_id': ObjectId('669ca9e954452054d92ab8d9'),
#  'geocode': {'latitude': 51.359586, 'longitude': 1.44305}}
# {'BusinessName': 'Beaches Cafe Bar',
#  'RatingValue': 5,
#  '_id': ObjectId('669ca9e954452054d92ab8da'),
#  'geocode': {'latitude': 51.359586, 'longitude': 1.44305}}
# {'BusinessName': 'Seafarer Restaurant',
#  'RatingValue': 5,
#  '_id': ObjectId('669ca9e954452054d92ab8dc'),
#  'geocode': {'latitude': 51.359586, 'longitude': 1.44305}}
# {'BusinessName': "Bessie's Tea Parlour",
#  'RatingValue': 5,
#  '_id': ObjectId('669ca9e954452054d92ab8dd'),
#  'geocode': {'latitude': 51.359586, 'longitude': 1.44305}}
# {'BusinessName': 'Sardinia',
#  'RatingValue': 5,
#  '_id': ObjectId('669ca9e954452054d92ab8de'),
#  'geocode': {'latitude': 51.358994, 'longitude': 1.442402}}
# {'BusinessName': 'Samworth & Mee',
#  'RatingValue': 5,
#  '_id': ObjectId('669ca9e954452054d92ab8df'),
#  'geocode': {'latitude': 51.358994, 'longitude': 1.442402}}
# {'BusinessName': "Raindell's",
#  'RatingValue': 5,
#  '_id': ObjectId('669ca9e954452054d92ab8e0'),
#  'geocode': {'latitude': 51.358994, 'longitude': 1.442402}}
# {'BusinessName': 'Prezzo',
#  'RatingValue': 5,
#  '_id': ObjectId('669ca9e954452054d92ab8e2'),
#  'geocode': {'latitude': 51.358994, 'longitude': 1.442402}}
# {'BusinessName': 'Albarino Tapas Restaurant Bar',
#  'RatingValue': 5,
#  '_id': ObjectId('669ca9e954452054d92ab8e3'),
#  'geocode': {'latitude': 51.359186, 'longitude': 1.442603}}
# {'BusinessName': 'Smokehouse',
#  'RatingValue': 5,
#  '_id': ObjectId('669ca9e954452054d92ab8e4'),
#  'geocode': {'latitude': 51.358994, 'longitude': 1.442402}}
# {'BusinessName': 'The Pickled Herring',
#  'RatingValue': 5,
#  '_id': ObjectId('669ca9e954452054d92ab8e6'),
#  'geocode': {'latitude': 51.36014, 'longitude': 1.443479}}
# {'BusinessName': 'Kyoto Sushi & Grill',
#  'RatingValue': 5,
#  '_id': ObjectId('669ca9e954452054d92ab8e7'),
#  'geocode': {'latitude': 51.335252, 'longitude': 1.417358}}
# {'BusinessName': 'Osteria Posillipo',
#  'RatingValue': 5,
#  '_id': ObjectId('669ca9e954452054d92ab8ea'),
#  'geocode': {'latitude': 51.358994, 'longitude': 1.442402}}
# {'BusinessName': 'The Dining Room',
#  'RatingValue': 5,
#  '_id': ObjectId('669ca9e954452054d92ab8ed'),
#  'geocode': {'latitude': 51.3592045, 'longitude': 1.4424843}}
# {'BusinessName': 'The Gardners Retreat Restaurant',
#  'RatingValue': 5,
#  '_id': ObjectId('669ca9e954452054d92ab8ee'),
#  'geocode': {'latitude': 51.3447151184082, 'longitude': 1.42712604999542}}
# {'BusinessName': 'Thai Four Two',
#  'RatingValue': 5,
#  '_id': ObjectId('669ca9e954452054d92ab8f6'),
#  'geocode': {'latitude': 51.357331, 'longitude': 1.439907}}
# {'BusinessName': 'Helter Skelter Nursery',
#  'RatingValue': 5,
#  '_id': ObjectId('669ca9e954452054d92ab8f7'),
#  'geocode': {'latitude': 51.357331, 'longitude': 1.439907}}
# {'BusinessName': 'Smiths Coffee Bar',
#  'RatingValue': 5,
#  '_id': ObjectId('669ca9e954452054d92ab8f8'),
#  'geocode': {'latitude': 51.358016007636, 'longitude': 1.44067142761883}}
# {'BusinessName': 'The Little Sicilian',
#  'RatingValue': 5,
#  '_id': ObjectId('669ca9e954452054d92ab8f9'),
#  'geocode': {'latitude': 51.357331, 'longitude': 1.439907}}
# {'BusinessName': "Anne's Restaurant",
#  'RatingValue': 5,
#  '_id': ObjectId('669ca9e954452054d92ab8fa'),
#  'geocode': {'latitude': 51.0838011273513, 'longitude': 1.15552850032491}}
# {'BusinessName': 'Spice Cottage',
#  'RatingValue': 3,
#  '_id': ObjectId('669ca9e954452054d92ab8ff'),
#  'geocode': {'latitude': 51.358006, 'longitude': 1.440503}}
# {'BusinessName': 'Please Sir',
#  'RatingValue': 5,
#  '_id': ObjectId('669ca9e954452054d92ab906'),
#  'geocode': {'latitude': 51.358827, 'longitude': 1.441039}}
# {'BusinessName': 'Pork & Co Limited',
#  'RatingValue': 5,
#  '_id': ObjectId('669ca9e954452054d92ab908'),
#  'geocode': {'latitude': 51.358827, 'longitude': 1.441039}}
# {'BusinessName': 'Mr Whippets Cafe',
#  'RatingValue': None,
#  '_id': ObjectId('669ca9e954452054d92ab909'),
#  'geocode': {'latitude': 51.0737795, 'longitude': 1.1447965}}
# {'BusinessName': "Ed's Cafe",
#  'RatingValue': 5,
#  '_id': ObjectId('669ca9e954452054d92ab90d'),
#  'geocode': {'latitude': 51.358506, 'longitude': 1.440627}}
# {'BusinessName': 'The Crown',
#  'RatingValue': 4,
#  '_id': ObjectId('669ca9e954452054d92ab90e'),
#  'geocode': {'latitude': 51.358506, 'longitude': 1.440627}}
# {'BusinessName': 'Beano Cafe',
#  'RatingValue': 5,
#  '_id': ObjectId('669ca9e954452054d92ab912'),
#  'geocode': {'latitude': 51.335725, 'longitude': 1.416546}}
# {'BusinessName': 'Orchard Lane Coffee House',
#  'RatingValue': 4,
#  '_id': ObjectId('669ca9e954452054d92ab915'),
#  'geocode': {'latitude': 51.073767, 'longitude': 1.144502}}
# {'BusinessName': 'The Dog House',
#  'RatingValue': 5,
#  '_id': ObjectId('669ca9e954452054d92ab91b'),
#  'geocode': {'latitude': 51.073327, 'longitude': 1.143459}}
# {'BusinessName': 'Cafe Pierre',
#  'RatingValue': 5,
#  '_id': ObjectId('669ca9e954452054d92ab91e'),
#  'geocode': {'latitude': 51.073328, 'longitude': 1.143459}}
# {'BusinessName': 'CCCP Restaurant',
#  'RatingValue': 5,
#  '_id': ObjectId('669ca9e954452054d92ab929'),
#  'geocode': {'latitude': 51.336311, 'longitude': 1.415901}}
# {'BusinessName': 'The Kent School of English',
#  'RatingValue': 5,
#  '_id': ObjectId('669ca9e954452054d92ab936'),
#  'geocode': {'latitude': 51.359205, 'longitude': 1.439185}}
# {'BusinessName': 'Spice Fusion',
#  'RatingValue': 5,
#  '_id': ObjectId('669ca9e954452054d92ab93d'),
#  'geocode': {'latitude': 51.336968, 'longitude': 1.415562}}
# {'BusinessName': 'The Curry House',
#  'RatingValue': 5,
#  '_id': ObjectId('669ca9e954452054d92ab940'),
#  'geocode': {'latitude': 51.336367, 'longitude': 1.414583}}
# {'BusinessName': "Sinatra's",
#  'RatingValue': 5,
#  '_id': ObjectId('669ca9e954452054d92ab945'),
#  'geocode': {'latitude': 51.359544, 'longitude': 1.438075}}
# {'BusinessName': 'McDonalds Restaurant',
#  'RatingValue': 5,
#  '_id': ObjectId('669ca9e954452054d92ab94e'),
#  'geocode': {'latitude': 51.095976, 'longitude': 1.163794}}
# {'BusinessName': 'Play Wise',
#  'RatingValue': 5,
#  '_id': ObjectId('669ca9e954452054d92ab952'),
#  'geocode': {'latitude': 51.3407440185547, 'longitude': 1.41773903369904}}
# {'BusinessName': 'Ramsgate Sports Centre',
#  'RatingValue': 5,
#  '_id': ObjectId('669ca9e954452054d92ab958'),
#  'geocode': {'latitude': 51.336844, 'longitude': 1.413341}}
# {'BusinessName': 'KFC',
#  'RatingValue': 5,
#  '_id': ObjectId('669ca9e954452054d92ab959'),
#  'geocode': {'latitude': 51.086441, 'longitude': 1.152861}}
# {'BusinessName': 'The Boating Pool',
#  'RatingValue': 5,
#  '_id': ObjectId('669ca9e954452054d92ab95e'),
#  'geocode': {'latitude': 51.32779, 'longitude': 1.403005}}
# {'BusinessName': 'The Boating Pool',
#  'RatingValue': 5,
#  '_id': ObjectId('669ca9e954452054d92ab960'),
#  'geocode': {'latitude': 51.32779, 'longitude': 1.403005}}
# {'BusinessName': 'The Amber Palace',
#  'RatingValue': None,
#  '_id': ObjectId('669ca9e954452054d92ab963'),
#  'geocode': {'latitude': 51.359885, 'longitude': 1.436534}}
# {'BusinessName': 'Kope & Loko',
#  'RatingValue': 5,
#  '_id': ObjectId('669ca9e954452054d92ab964'),
#  'geocode': {'latitude': 51.3598747253418, 'longitude': 1.43654704093933}}
# {'BusinessName': 'Creta',
#  'RatingValue': 5,
#  '_id': ObjectId('669ca9e954452054d92ab965'),
#  'geocode': {'latitude': 51.3598747253418, 'longitude': 1.43654704093933}}
# {'BusinessName': 'Cafe Grill',
#  'RatingValue': 5,
#  '_id': ObjectId('669ca9e954452054d92ab96a'),
#  'geocode': {'latitude': 51.359886, 'longitude': 1.436535}}
# {'BusinessName': 'Broadstairs & St Peters Bowling Club',
#  'RatingValue': 5,
#  '_id': ObjectId('669ca9e954452054d92ab96d'),
#  'geocode': {'latitude': 51.360211, 'longitude': 1.436804}}
# {'BusinessName': 'Cardak Meze & Grill',
#  'RatingValue': 5,
#  '_id': ObjectId('669ca9e954452054d92ab970'),
#  'geocode': {'latitude': 51.359615, 'longitude': 1.43594}}
# {'BusinessName': 'Green Coffee House and Wine Bar',
#  'RatingValue': 5,
#  '_id': ObjectId('669ca9e954452054d92ab97d'),
#  'geocode': {'latitude': 51.332431, 'longitude': 1.406737}}
# {'BusinessName': 'Beano Cafe',
#  'RatingValue': 5,
#  '_id': ObjectId('669ca9e954452054d92ab97f'),
#  'geocode': {'latitude': 51.332431, 'longitude': 1.406737}}
# {'BusinessName': 'Basils',
#  'RatingValue': 4,
#  '_id': ObjectId('669ca9e954452054d92ab982'),
#  'geocode': {'latitude': 51.086705, 'longitude': 1.151065}}
# {'BusinessName': 'Captain Webb Coffee Co',
#  'RatingValue': 4,
#  '_id': ObjectId('669ca9e954452054d92ab985'),
#  'geocode': {'latitude': 51.0867042541504, 'longitude': 1.15106499195099}}
# {'BusinessName': 'Gurkha Palace',
#  'RatingValue': 5,
#  '_id': ObjectId('669ca9e954452054d92ab991'),
#  'geocode': {'latitude': 51.082027, 'longitude': 1.146077}}
# {'BusinessName': 'Station Fish Bar & Grill',
#  'RatingValue': 5,
#  '_id': ObjectId('669ca9e954452054d92ab999'),
#  'geocode': {'latitude': 51.359932, 'longitude': 1.43434}}
# {'BusinessName': "Daa's Thai Diner",
#  'RatingValue': 5,
#  '_id': ObjectId('669ca9e954452054d92ab9a0'),
#  'geocode': {'latitude': 51.360118, 'longitude': 1.435058}}
# {'BusinessName': 'Windmill Cafe',
#  'RatingValue': 5,
#  '_id': ObjectId('669ca9e954452054d92ab9a2'),
#  'geocode': {'latitude': 51.086667, 'longitude': 1.149477}}
# {'BusinessName': 'The Beano Cafe',
#  'RatingValue': 5,
#  '_id': ObjectId('669ca9e954452054d92ab9b7'),
#  'geocode': {'latitude': 51.360134, 'longitude': 1.432071}}
# {'BusinessName': 'St Lawrence Bowls Club',
#  'RatingValue': 5,
#  '_id': ObjectId('669ca9e954452054d92ab9c4'),
#  'geocode': {'latitude': 51.338569, 'longitude': 1.408758}}
# {'BusinessName': 'Thanet Winter Shelter',
#  'RatingValue': 5,
#  '_id': ObjectId('669ca9e954452054d92ab9c5'),
#  'geocode': {'latitude': 51.361293, 'longitude': 1.4321}}
# {'BusinessName': 'Broadstairs English Centre',
#  'RatingValue': 5,
#  '_id': ObjectId('669ca9e954452054d92ab9c7'),
#  'geocode': {'latitude': 51.361293, 'longitude': 1.4321}}
# {'BusinessName': 'Beanos Cafe',
#  'RatingValue': 5,
#  '_id': ObjectId('669ca9e954452054d92ab9d1'),
#  'geocode': {'latitude': 51.087583, 'longitude': 1.147183}}
# {'BusinessName': 'Everest Spice Fusion',
#  'RatingValue': 4,
#  '_id': ObjectId('669ca9e954452054d92ab9eb'),
#  'geocode': {'latitude': 51.087802, 'longitude': 1.146084}}
# {'BusinessName': 'Army - Premier Shop',
#  'RatingValue': 5,
#  '_id': ObjectId('669ca9e954452054d92ab9f1'),
#  'geocode': {'latitude': 51.07912, 'longitude': 1.136784}}
# {'BusinessName': 'Army - Junior Ranks Mess',
#  'RatingValue': 5,
#  '_id': ObjectId('669ca9e954452054d92ab9f2'),
#  'geocode': {'latitude': 51.07912, 'longitude': 1.136784}}
# {'BusinessName': 'Army - Officers Mess',
#  'RatingValue': 5,
#  '_id': ObjectId('669ca9e954452054d92ab9f3'),
#  'geocode': {'latitude': 51.07912, 'longitude': 1.136784}}
# {'BusinessName': 'Army - Sergeants Mess',
#  'RatingValue': 5,
#  '_id': ObjectId('669ca9e954452054d92ab9f5'),
#  'geocode': {'latitude': 51.07912, 'longitude': 1.136784}}
# {'BusinessName': 'Bannatynes Health Club',
#  'RatingValue': 5,
#  '_id': ObjectId('669ca9e954452054d92aba02'),
#  'geocode': {'latitude': 51.094664, 'longitude': 1.152135}}
# {'BusinessName': 'Finns',
#  'RatingValue': 5,
#  '_id': ObjectId('669ca9e954452054d92aba03'),
#  'geocode': {'latitude': 51.087952, 'longitude': 1.145194}}
# {'BusinessName': 'Dawns Delight',
#  'RatingValue': 5,
#  '_id': ObjectId('669ca9e954452054d92aba07'),
#  'geocode': {'latitude': 51.087952, 'longitude': 1.145194}}
# {'BusinessName': 'Chai Coffee Nashta',
#  'RatingValue': None,
#  '_id': ObjectId('669ca9e954452054d92aba0b'),
#  'geocode': {'latitude': 51.0877039, 'longitude': 1.1447896}}
# {'BusinessName': 'New Himalayan Cafe',
#  'RatingValue': 3,
#  '_id': ObjectId('669ca9e954452054d92aba10'),
#  'geocode': {'latitude': 51.087712, 'longitude': 1.144749}}
# {'BusinessName': 'Refresh Cafe',
#  'RatingValue': 4,
#  '_id': ObjectId('669ca9e954452054d92aba39'),
#  'geocode': {'latitude': 51.095079, 'longitude': 1.150735}}
# {'BusinessName': 'Light Railway Restaurant',
#  'RatingValue': 5,
#  '_id': ObjectId('669ca9e954452054d92aba3a'),
#  'geocode': {'latitude': 50.915115, 'longitude': 0.966514}}
# {'BusinessName': 'Pumpkin',
#  'RatingValue': 5,
#  '_id': ObjectId('669ca9e954452054d92aba3e'),
#  'geocode': {'latitude': 51.3409817, 'longitude': 1.4061618}}
# {'BusinessName': 'St Lawrence Tandoori',
#  'RatingValue': 4,
#  '_id': ObjectId('669ca9e954452054d92aba41'),
#  'geocode': {'latitude': 51.337822, 'longitude': 1.402629}}
# {'BusinessName': 'Sexy Burger',
#  'RatingValue': 5,
#  '_id': ObjectId('669ca9e954452054d92aba45'),
#  'geocode': {'latitude': 51.3361178, 'longitude': 1.4005511}}
# {'BusinessName': 'Dungeness A Power Station',
#  'RatingValue': 5,
#  '_id': ObjectId('669ca9e954452054d92aba46'),
#  'geocode': {'latitude': 50.9133071899414, 'longitude': 0.964037001132965}}
# {'BusinessName': 'Wings n Dat',
#  'RatingValue': 4,
#  '_id': ObjectId('669ca9e954452054d92aba4c'),
#  'geocode': {'latitude': 51.0879795, 'longitude': 1.1425621}}
# {'BusinessName': 'Prince of India',
#  'RatingValue': 4,
#  '_id': ObjectId('669ca9e954452054d92aba4e'),
#  'geocode': {'latitude': 51.087175, 'longitude': 1.141614}}
# {'BusinessName': 'Lemon Leaf Restaurant & Bar',
#  'RatingValue': 5,
#  '_id': ObjectId('669ca9e954452054d92aba54'),
#  'geocode': {'latitude': 51.087931, 'longitude': 1.142279}}
# {'BusinessName': 'Curious Crafts of Cheriton & Tearoom',
#  'RatingValue': 5,
#  '_id': ObjectId('669ca9e954452054d92aba55'),
#  'geocode': {'latitude': 51.0880283897589, 'longitude': 1.14236459635779}}
# {'BusinessName': 'Daows Thai Kitchen',
#  'RatingValue': 5,
#  '_id': ObjectId('669ca9e954452054d92aba5c'),
#  'geocode': {'latitude': 51.084261, 'longitude': 1.137589}}
# {'BusinessName': '3 in 1 Cafe',
#  'RatingValue': 3,
#  '_id': ObjectId('669ca9e954452054d92aba5e'),
#  'geocode': {'latitude': 51.084261, 'longitude': 1.137589}}
# {'BusinessName': 'Kidz Planet',
#  'RatingValue': 5,
#  '_id': ObjectId('669ca9e954452054d92aba5f'),
#  'geocode': {'latitude': 51.093315, 'longitude': 1.146772}}
# {'BusinessName': 'The Pavilion Cafe',
#  'RatingValue': 5,
#  '_id': ObjectId('669ca9e954452054d92aba71'),
#  'geocode': {'latitude': 51.3668785095215, 'longitude': 1.43093705177307}}
# {'BusinessName': 'Joss Bay Cafe',
#  'RatingValue': 5,
#  '_id': ObjectId('669ca9e954452054d92aba78'),
#  'geocode': {'latitude': 51.381812, 'longitude': 1.444029}}
# {'BusinessName': 'Laurel Court Restaurant',
#  'RatingValue': 5,
#  '_id': ObjectId('669ca9e954452054d92aba7b'),
#  'geocode': {'latitude': 51.091013, 'longitude': 1.14106}}
# {'BusinessName': 'EDF  Dungeness B Power Station',
#  'RatingValue': 5,
#  '_id': ObjectId('669ca9e954452054d92aba7f'),
#  'geocode': {'latitude': 50.9134254455566, 'longitude': 0.959720015525818}}
# {'BusinessName': 'Lilys',
#  'RatingValue': 5,
#  '_id': ObjectId('669ca9e954452054d92aba81'),
#  'geocode': {'latitude': 51.1150651, 'longitude': 1.1651994}}
# {'BusinessName': 'The Cooks Table',
#  'RatingValue': 4,
#  '_id': ObjectId('669ca9e954452054d92aba8a'),
#  'geocode': {'latitude': 51.110991, 'longitude': 1.160391}}
# {'BusinessName': 'The Corner Coffee House',
#  'RatingValue': 5,
#  '_id': ObjectId('669ca9e954452054d92aba8f'),
#  'geocode': {'latitude': 51.343189, 'longitude': 1.401173}}
# {'BusinessName': 'Aspendos Hawkinge',
#  'RatingValue': 4,
#  '_id': ObjectId('669ca9e954452054d92aba90'),
#  'geocode': {'latitude': 51.1150651, 'longitude': 1.1651994}}
# {'BusinessName': 'Buttons Pre-School (Fegans)',
#  'RatingValue': 5,
#  '_id': ObjectId('669ca9e954452054d92aba91'),
#  'geocode': {'latitude': 51.343189, 'longitude': 1.401173}}
# {'BusinessName': 'Under 1 Roof Kids Thanet',
#  'RatingValue': 5,
#  '_id': ObjectId('669ca9e954452054d92aba9d'),
#  'geocode': {'latitude': 51.3518028259277, 'longitude': 1.40902197360992}}
# {'BusinessName': 'Stewarts Cafe',
#  'RatingValue': 5,
#  '_id': ObjectId('669ca9e954452054d92abaa8'),
#  'geocode': {'latitude': 51.3485244, 'longitude': 1.4053856}}
# {'BusinessName': 'Hawkinge House',
#  'RatingValue': 5,
#  '_id': ObjectId('669ca9e954452054d92abaa9'),
#  'geocode': {'latitude': 51.110454, 'longitude': 1.158654}}
# {'BusinessName': 'Blue Apple Contract Catering',
#  'RatingValue': 5,
#  '_id': ObjectId('669ca9e954452054d92abab0'),
#  'geocode': {'latitude': 51.3539278, 'longitude': 1.4107282}}
# {'BusinessName': 'Rosie Lea Tea',
#  'RatingValue': None,
#  '_id': ObjectId('669ca9e954452054d92abab4'),
#  'geocode': {'latitude': 51.369967, 'longitude': 1.427116}}
# {'BusinessName': 'Halfway House Cafe',
#  'RatingValue': 5,
#  '_id': ObjectId('669ca9e954452054d92ababa'),
#  'geocode': {'latitude': 51.377667, 'longitude': 1.434777}}
# {'BusinessName': 'Golf Club Restaurant',
#  'RatingValue': 5,
#  '_id': ObjectId('669ca9e954452054d92ababb'),
#  'geocode': {'latitude': 51.377667, 'longitude': 1.434777}}
# {'BusinessName': 'Staple',
#  'RatingValue': 5,
#  '_id': ObjectId('669ca9e954452054d92ababc'),
#  'geocode': {'latitude': 51.3743057250977, 'longitude': 1.43155097961426}}
# {'BusinessName': 'Hawkinge Community Football & Sports',
#  'RatingValue': 5,
#  '_id': ObjectId('669ca9e954452054d92abac7'),
#  'geocode': {'latitude': 51.1230953, 'longitude': 1.1688388}}
# {'BusinessName': 'Army - Comanding Officers Mess',
#  'RatingValue': 5,
#  '_id': ObjectId('669ca9e954452054d92abacd'),
#  'geocode': {'latitude': 51.085549, 'longitude': 1.12972}}
# {'BusinessName': 'Naafi Gb Cinque Club',
#  'RatingValue': 5,
#  '_id': ObjectId('669ca9e954452054d92abacf'),
#  'geocode': {'latitude': 51.085549, 'longitude': 1.12972}}
# {'BusinessName': 'Army - Risborough - Napier 33 (Other',
#  'RatingValue': 5,
#  '_id': ObjectId('669ca9e954452054d92abad1'),
#  'geocode': {'latitude': 51.085549, 'longitude': 1.12972}}
# {'BusinessName': 'Beano Cafe',
#  'RatingValue': 4,
#  '_id': ObjectId('669ca9e954452054d92abad6'),
#  'geocode': {'latitude': 51.344663, 'longitude': 1.398425}}
# {'BusinessName': 'Peninsula',
#  'RatingValue': 5,
#  '_id': ObjectId('669ca9e954452054d92abada'),
# ...
#  '_id': ObjectId('669ca9eb54452054d92b4d38'),
#  'geocode': {'latitude': 51.9791870117188, 'longitude': 0.263381004333496}}
# {'BusinessName': 'Blues Cafe',
#  'RatingValue': None,
#  '_id': ObjectId('669ca9eb54452054d92b4d3e'),
#  'geocode': {'latitude': 51.8610458374023, 'longitude': 0.14206899702549}}
# {'BusinessName': 'The Doorstep Cafe',
#  'RatingValue': 5,
#  '_id': ObjectId('669ca9eb54452054d92b4d44'),
#  'geocode': {'latitude': 51.7539328, 'longitude': 0.0307501}}
# {'BusinessName': 'Tyndalls',
#  'RatingValue': 5,
#  '_id': ObjectId('669ca9eb54452054d92b4d63'),
#  'geocode': {'latitude': 51.744759, 'longitude': 0.012795}}
# {'BusinessName': 'Chives Catering',
#  'RatingValue': None,
#  '_id': ObjectId('669ca9eb54452054d92b4d6d'),
#  'geocode': {'latitude': 51.877387, 'longitude': 0.143528}}
# {'BusinessName': 'Just at the Station',
#  'RatingValue': 5,
#  '_id': ObjectId('669ca9eb54452054d92b4d73'),
#  'geocode': {'latitude': 51.774388, 'longitude': 0.037842}}
# {'BusinessName': 'Sewards End Village Hall',
#  'RatingValue': None,
#  '_id': ObjectId('669ca9eb54452054d92b4d75'),
#  'geocode': {'latitude': 52.0209541320801, 'longitude': 0.287149012088776}}
# {'BusinessName': 'Servest Food Company',
#  'RatingValue': 5,
#  '_id': ObjectId('669ca9eb54452054d92b4d76'),
#  'geocode': {'latitude': 51.87507, 'longitude': 0.135457}}
# {'BusinessName': 'Costa Coffee',
#  'RatingValue': 5,
#  '_id': ObjectId('669ca9eb54452054d92b4d79'),
#  'geocode': {'latitude': 51.87507, 'longitude': 0.135457}}
# {'BusinessName': 'The Boathouse Cafe Bar',
#  'RatingValue': 5,
#  '_id': ObjectId('669ca9eb54452054d92b4d7b'),
#  'geocode': {'latitude': 51.773457, 'longitude': 0.031364}}
# {'BusinessName': 'River Palace Cafe',
#  'RatingValue': 1,
#  '_id': ObjectId('669ca9eb54452054d92b4d7d'),
#  'geocode': {'latitude': 51.754526, 'longitude': 0.006853}}
# {'BusinessName': 'Rosey Lea',
#  'RatingValue': 5,
#  '_id': ObjectId('669ca9eb54452054d92b4d7e'),
#  'geocode': {'latitude': 51.886458, 'longitude': 0.140661}}
# {'BusinessName': 'Cortland Fibron BX',
#  'RatingValue': None,
#  '_id': ObjectId('669ca9eb54452054d92b4d7f'),
#  'geocode': {'latitude': 51.7577536, 'longitude': 0.0093405}}
# {'BusinessName': 'Henry Moore Foundation Visitor Cafe',
#  'RatingValue': 5,
#  '_id': ObjectId('669ca9eb54452054d92b4d80'),
#  'geocode': {'latitude': 51.836961, 'longitude': 0.086347}}
# {'BusinessName': 'Copleys',
#  'RatingValue': 2,
#  '_id': ObjectId('669ca9eb54452054d92b4d81'),
#  'geocode': {'latitude': 51.8371602, 'longitude': 0.0859129}}
# {'BusinessName': 'Beefeater',
#  'RatingValue': 5,
#  '_id': ObjectId('669ca9eb54452054d92b4d93'),
#  'geocode': {'latitude': 52.0117553, 'longitude': 0.2586366}}
# {'BusinessName': 'Costa Coffee',
#  'RatingValue': 5,
#  '_id': ObjectId('669ca9eb54452054d92b4da0'),
#  'geocode': {'latitude': 52.0131443, 'longitude': 0.2579578}}
# {'BusinessName': 'Hi Bar Ltd',
#  'RatingValue': 4,
#  '_id': ObjectId('669ca9eb54452054d92b4da3'),
#  'geocode': {'latitude': 51.770039, 'longitude': 0.006817}}
# {'BusinessName': 'Chase Health and Fitness',
#  'RatingValue': None,
#  '_id': ObjectId('669ca9eb54452054d92b4da8'),
#  'geocode': {'latitude': 51.7654907, 'longitude': 0.0017568}}
# {'BusinessName': 'Parklands Quendon Hall Events Venue',
#  'RatingValue': 5,
#  '_id': ObjectId('669ca9eb54452054d92b4dac'),
#  'geocode': {'latitude': 51.963934, 'longitude': 0.202666}}
# {'BusinessName': 'Costa Coffee',
#  'RatingValue': 5,
#  '_id': ObjectId('669ca9eb54452054d92b4dad'),
#  'geocode': {'latitude': 51.890731, 'longitude': 0.159493}}
# {'BusinessName': 'Turpins Indoor Bowls Club',
#  'RatingValue': 5,
#  '_id': ObjectId('669ca9eb54452054d92b4db4'),
#  'geocode': {'latitude': 52.015453, 'longitude': 0.251585}}
# {'BusinessName': 'Lord Butler Leisure Centre',
#  'RatingValue': None,
#  '_id': ObjectId('669ca9eb54452054d92b4db6'),
#  'geocode': {'latitude': 52.015453, 'longitude': 0.251585}}
# {'BusinessName': 'Quinntessential Catering',
#  'RatingValue': 4,
#  '_id': ObjectId('669ca9eb54452054d92b4dba'),
#  'geocode': {'latitude': 51.9804229736328, 'longitude': 0.214761003851891}}
# {'BusinessName': "Fill's Cafe",
#  'RatingValue': 5,
#  '_id': ObjectId('669ca9eb54452054d92b4dbf'),
#  'geocode': {'latitude': 52.020704, 'longitude': 0.255813}}
# {'BusinessName': 'Hoddesdon Town Football Club',
#  'RatingValue': 5,
#  '_id': ObjectId('669ca9eb54452054d92b4dc1'),
#  'geocode': {'latitude': 51.764853, 'longitude': 0.002226}}
# {'BusinessName': 'Wood Street Coffee Roasters Ltd',
#  'RatingValue': None,
#  '_id': ObjectId('669ca9eb54452054d92b4dc4'),
#  'geocode': {'latitude': 52.020704, 'longitude': 0.255813}}
# {'BusinessName': 'Jam Hospitality Limited',
#  'RatingValue': None,
#  '_id': ObjectId('669ca9eb54452054d92b4dc8'),
#  'geocode': {'latitude': 51.8744087219238, 'longitude': 0.105397000908852}}
# {'BusinessName': 'Hope Community Hub-Make Lunch',
#  'RatingValue': 5,
#  '_id': ObjectId('669ca9eb54452054d92b4dc9'),
#  'geocode': {'latitude': 52.0207061767578, 'longitude': 0.255813002586365}}
# {'BusinessName': 'New Life Pentecostal Church',
#  'RatingValue': None,
#  '_id': ObjectId('669ca9eb54452054d92b4dca'),
#  'geocode': {'latitude': 52.0190575, 'longitude': 0.2534403}}
# {'BusinessName': 'Radhuni Indian Cuisine',
#  'RatingValue': 2,
#  '_id': ObjectId('669ca9eb54452054d92b4dcf'),
#  'geocode': {'latitude': 51.984147, 'longitude': 0.21429}}
# {'BusinessName': 'Maltings Cafe Ltd',
#  'RatingValue': None,
#  '_id': ObjectId('669ca9eb54452054d92b4de4'),
#  'geocode': {'latitude': 51.78746, 'longitude': 0.008764}}
# {'BusinessName': 'SOKA Catering & Events Ltd',
#  'RatingValue': 5,
#  '_id': ObjectId('669ca9eb54452054d92b4de6'),
#  'geocode': {'latitude': 51.7872058, 'longitude': 0.0081845}}
# {'BusinessName': 'Wrights Fish & Chips',
#  'RatingValue': None,
#  '_id': ObjectId('669ca9eb54452054d92b4dee'),
#  'geocode': {'latitude': 52.013445, 'longitude': 0.238048}}
# {'BusinessName': 'Deja Vu',
#  'RatingValue': 5,
#  '_id': ObjectId('669ca9eb54452054d92b4df0'),
#  'geocode': {'latitude': 52.013445, 'longitude': 0.238048}}
# {'BusinessName': 'Saffron Walden Entertainments',
#  'RatingValue': 3,
#  '_id': ObjectId('669ca9eb54452054d92b4df8'),
#  'geocode': {'latitude': 52.0165115, 'longitude': 0.2397758}}
# {'BusinessName': "Fast Eddie's Community Cafe CIC (Fairycroft House)",
#  'RatingValue': 5,
#  '_id': ObjectId('669ca9eb54452054d92b4dfd'),
#  'geocode': {'latitude': 52.0213323, 'longitude': 0.2436851}}
# {'BusinessName': 'Taste Of Raj',
#  'RatingValue': 4,
#  '_id': ObjectId('669ca9eb54452054d92b4dfe'),
#  'geocode': {'latitude': 51.788905, 'longitude': 0.007828}}
# {'BusinessName': "Libby's Coffee Shop",
#  'RatingValue': 5,
#  '_id': ObjectId('669ca9eb54452054d92b4e02'),
#  'geocode': {'latitude': 51.788147, 'longitude': 0.005387}}
# {'BusinessName': 'Khunnai Thai Restaurant',
#  'RatingValue': 1,
#  '_id': ObjectId('669ca9eb54452054d92b4e04'),
#  'geocode': {'latitude': 51.788451, 'longitude': 0.005459}}
# {'BusinessName': "Hopley's Cafe",
#  'RatingValue': 5,
#  '_id': ObjectId('669ca9eb54452054d92b4e0e'),
#  'geocode': {'latitude': 51.854985, 'longitude': 0.071875}}
# {'BusinessName': 'Debden Grange Retirement Village',
#  'RatingValue': 5,
#  '_id': ObjectId('669ca9eb54452054d92b4e0f'),
#  'geocode': {'latitude': 51.9877271, 'longitude': 0.2075142}}
# {'BusinessName': 'Monday Muscles',
#  'RatingValue': None,
#  '_id': ObjectId('669ca9eb54452054d92b4e10'),
#  'geocode': {'latitude': 51.8855259, 'longitude': 0.1026748}}
# {'BusinessName': "D'Art Waffle",
#  'RatingValue': 5,
#  '_id': ObjectId('669ca9eb54452054d92b4e18'),
#  'geocode': {'latitude': 52.0197295, 'longitude': 0.2396961}}
# {'BusinessName': "Kim's Tea And Coffee House",
#  'RatingValue': 5,
#  '_id': ObjectId('669ca9eb54452054d92b4e1d'),
#  'geocode': {'latitude': 52.023066, 'longitude': 0.241836}}
# {'BusinessName': 'Bangkok Thai Restaurant',
#  'RatingValue': 2,
#  '_id': ObjectId('669ca9eb54452054d92b4e20'),
#  'geocode': {'latitude': 52.02345, 'longitude': 0.242002}}
# {'BusinessName': 'The Court Yard (Tiptree)',
#  'RatingValue': 5,
#  '_id': ObjectId('669ca9eb54452054d92b4e23'),
#  'geocode': {'latitude': 52.023874, 'longitude': 0.242387}}
# {'BusinessName': 'Dead Time Ltd',
#  'RatingValue': 5,
#  '_id': ObjectId('669ca9eb54452054d92b4e24'),
#  'geocode': {'latitude': 52.0238647460938, 'longitude': 0.242400005459785}}
# {'BusinessName': 'Starbucks Coffee',
#  'RatingValue': 5,
#  '_id': ObjectId('669ca9eb54452054d92b4e26'),
#  'geocode': {'latitude': 52.0232479, 'longitude': 0.2416286}}
# {'BusinessName': "EM's Coffee Bar",
#  'RatingValue': 5,
#  '_id': ObjectId('669ca9eb54452054d92b4e29'),
#  'geocode': {'latitude': 51.787958, 'longitude': 0.001188}}
# {'BusinessName': 'The Curiosity Fair',
#  'RatingValue': 5,
#  '_id': ObjectId('669ca9eb54452054d92b4e2a'),
#  'geocode': {'latitude': 52.021415, 'longitude': 0.239276}}
# {'BusinessName': 'The Saffron Suite',
#  'RatingValue': 5,
#  '_id': ObjectId('669ca9eb54452054d92b4e2c'),
#  'geocode': {'latitude': 52.0214157104492, 'longitude': 0.239276006817818}}
# {'BusinessName': 'The Piano',
#  'RatingValue': 5,
#  '_id': ObjectId('669ca9eb54452054d92b4e2d'),
#  'geocode': {'latitude': 52.023215, 'longitude': 0.241071}}
# {'BusinessName': 'Bicicletta',
#  'RatingValue': 5,
#  '_id': ObjectId('669ca9eb54452054d92b4e30'),
#  'geocode': {'latitude': 52.023024, 'longitude': 0.240741}}
# {'BusinessName': 'Lokma (CK Saffron Ltd)',
#  'RatingValue': 4,
#  '_id': ObjectId('669ca9eb54452054d92b4e31'),
#  'geocode': {'latitude': 52.02195, 'longitude': 0.239551}}
# {'BusinessName': 'SW Baptist Church Lunch Club',
#  'RatingValue': 5,
#  '_id': ObjectId('669ca9eb54452054d92b4e32'),
#  'geocode': {'latitude': 52.02195, 'longitude': 0.239551}}
# {'BusinessName': 'Maze Cafe Restaurant',
#  'RatingValue': 5,
#  '_id': ObjectId('669ca9eb54452054d92b4e33'),
#  'geocode': {'latitude': 52.024096, 'longitude': 0.241611}}
# {'BusinessName': 'Pashas Grill',
#  'RatingValue': 4,
#  '_id': ObjectId('669ca9eb54452054d92b4e39'),
#  'geocode': {'latitude': 52.022557, 'longitude': 0.2398}}
# {'BusinessName': 'Indigo Indian Dining',
#  'RatingValue': 3,
#  '_id': ObjectId('669ca9eb54452054d92b4e3a'),
#  'geocode': {'latitude': 52.022557, 'longitude': 0.2398}}
# {'BusinessName': 'Costa',
#  'RatingValue': 5,
#  '_id': ObjectId('669ca9eb54452054d92b4e3b'),
#  'geocode': {'latitude': 52.0240475, 'longitude': 0.2412955}}
# {'BusinessName': 'Tea Amo',
#  'RatingValue': 5,
#  '_id': ObjectId('669ca9eb54452054d92b4e3c'),
#  'geocode': {'latitude': 52.022991, 'longitude': 0.240113}}
# {'BusinessName': 'Dough & Co',
#  'RatingValue': 3,
#  '_id': ObjectId('669ca9eb54452054d92b4e3d'),
#  'geocode': {'latitude': 52.022991, 'longitude': 0.240113}}
# {'BusinessName': 'The Curious Goat',
#  'RatingValue': 3,
#  '_id': ObjectId('669ca9eb54452054d92b4e40'),
#  'geocode': {'latitude': 52.023018, 'longitude': 0.240085}}
# {'BusinessName': 'Gluttons',
#  'RatingValue': 5,
#  '_id': ObjectId('669ca9eb54452054d92b4e41'),
#  'geocode': {'latitude': 52.0233622, 'longitude': 0.2403723}}
# {'BusinessName': 'Support 4 Sight',
#  'RatingValue': 5,
#  '_id': ObjectId('669ca9eb54452054d92b4e42'),
#  'geocode': {'latitude': 52.0225465, 'longitude': 0.2394545}}
# {'BusinessName': 'La Boite Ltd.',
#  'RatingValue': None,
#  '_id': ObjectId('669ca9eb54452054d92b4e43'),
#  'geocode': {'latitude': 52.0232225, 'longitude': 0.2402814}}
# {'BusinessName': 'Cafe Cou Cou',
#  'RatingValue': 5,
#  '_id': ObjectId('669ca9eb54452054d92b4e47'),
#  'geocode': {'latitude': 52.022786, 'longitude': 0.239534}}
# {'BusinessName': 'Angela Reed Cafe',
#  'RatingValue': 5,
#  '_id': ObjectId('669ca9eb54452054d92b4e4b'),
#  'geocode': {'latitude': 52.024123, 'longitude': 0.240606}}
# {'BusinessName': 'Joseph Barnes Wines Limited',
#  'RatingValue': 4,
#  '_id': ObjectId('669ca9eb54452054d92b4e4d'),
#  'geocode': {'latitude': 52.0245875, 'longitude': 0.2406678}}
# {'BusinessName': 'Mocha Cafe',
#  'RatingValue': 5,
#  '_id': ObjectId('669ca9eb54452054d92b4e4f'),
#  'geocode': {'latitude': 52.022935, 'longitude': 0.239294}}
# {'BusinessName': 'The Restaurant On Church Street',
#  'RatingValue': 5,
#  '_id': ObjectId('669ca9eb54452054d92b4e53'),
#  'geocode': {'latitude': 52.024145, 'longitude': 0.239937}}
# {'BusinessName': 'Chaters',
#  'RatingValue': None,
#  '_id': ObjectId('669ca9eb54452054d92b4e54'),
#  'geocode': {'latitude': 52.0240713, 'longitude': 0.2396241}}
# {'BusinessName': 'Jade Garden',
#  'RatingValue': 3,
#  '_id': ObjectId('669ca9eb54452054d92b4e58'),
#  'geocode': {'latitude': 52.024123, 'longitude': 0.240606}}
# {'BusinessName': 'Saffron Hall Bar',
#  'RatingValue': 5,
#  '_id': ObjectId('669ca9eb54452054d92b4e5d'),
#  'geocode': {'latitude': 52.017147064209, 'longitude': 0.231484994292259}}
# {'BusinessName': 'St Marys Church',
#  'RatingValue': None,
#  '_id': ObjectId('669ca9eb54452054d92b4e61'),
#  'geocode': {'latitude': 52.0250701904297, 'longitude': 0.238656997680664}}
# {'BusinessName': 'The Mogul Restaurant',
#  'RatingValue': 1,
#  '_id': ObjectId('669ca9eb54452054d92b4e65'),
#  'geocode': {'latitude': 52.02372, 'longitude': 0.238196}}
# {'BusinessName': 'St Marys C Of E Primary School',
#  'RatingValue': 5,
#  '_id': ObjectId('669ca9eb54452054d92b4e6e'),
#  'geocode': {'latitude': 52.026326, 'longitude': 0.241096}}
# {'BusinessName': 'Ananta',
#  'RatingValue': 3,
#  '_id': ObjectId('669ca9eb54452054d92b4e70'),
#  'geocode': {'latitude': 51.977888, 'longitude': 0.181523}}
# {'BusinessName': 'Audley End Miniature Railway Cafe & Shop',
#  'RatingValue': 4,
#  '_id': ObjectId('669ca9eb54452054d92b4e76'),
#  'geocode': {'latitude': 52.0188140869141, 'longitude': 0.220520004630089}}
# {'BusinessName': 'Wendens Ambo Pre School',
#  'RatingValue': 5,
#  '_id': ObjectId('669ca9eb54452054d92b4e79'),
#  'geocode': {'latitude': 52.005558, 'longitude': 0.204666}}
# {'BusinessName': 'Audley End House \\& Restaurant',
#  'RatingValue': 5,
#  '_id': ObjectId('669ca9eb54452054d92b4e7b'),
#  'geocode': {'latitude': 52.020834, 'longitude': 0.22059}}
# {'BusinessName': 'The Cricketers',
#  'RatingValue': 5,
#  '_id': ObjectId('669ca9eb54452054d92b4e7d'),
#  'geocode': {'latitude': 51.973655, 'longitude': 0.158531}}
# {'BusinessName': 'Clavering Village Hall',
#  'RatingValue': None,
#  '_id': ObjectId('669ca9eb54452054d92b4e7f'),
#  'geocode': {'latitude': 51.970286, 'longitude': 0.153405}}
# {'BusinessName': 'Brook Cottage Riding School',
#  'RatingValue': None,
#  '_id': ObjectId('669ca9eb54452054d92b4e8d'),
#  'geocode': {'latitude': 51.929101, 'longitude': 0.087039}}
# {'BusinessName': 'China Garden',
#  'RatingValue': 4,
#  '_id': ObjectId('669ca9eb54452054d92b4e97'),
#  'geocode': {'latitude': 51.884858, 'longitude': 0.02377}}
# {'BusinessName': "Poppy's Tea Room",
#  'RatingValue': 5,
#  '_id': ObjectId('669ca9eb54452054d92b4e98'),
#  'geocode': {'latitude': 51.9826787, 'longitude': 0.1194518}}
# {'BusinessName': 'Sliderman',
#  'RatingValue': 5,
#  '_id': ObjectId('669ca9eb54452054d92b4eac'),
#  'geocode': {'latitude': 51.9994109, 'longitude': 0.1092515}}
# {'BusinessName': 'Leapfrogs Pre-School',
#  'RatingValue': 5,
#  '_id': ObjectId('669ca9eb54452054d92b4eb0'),
#  'geocode': {'latitude': 51.960014, 'longitude': 0.05443}}
# {'BusinessName': 'Something Lovely Ltd',
#  'RatingValue': 5,
#  '_id': ObjectId('669ca9eb54452054d92b4eb2'),
#  'geocode': {'latitude': 51.891722, 'longitude': 0.013105}}
# {'BusinessName': 'March Hare Tearoom',
#  'RatingValue': 5,
#  '_id': ObjectId('669ca9eb54452054d92b4eb8'),
#  'geocode': {'latitude': 51.949541, 'longitude': 0.021544}}
# {'BusinessName': 'Old Swan Tea Shop',
#  'RatingValue': 5,
#  '_id': ObjectId('669ca9eb54452054d92b4eba'),
#  'geocode': {'latitude': 51.94763, 'longitude': 0.020803}}
# {'BusinessName': 'Tortoise Tea Room',
#  'RatingValue': 3,
#  '_id': ObjectId('669ca9eb54452054d92b4ebd'),
#  'geocode': {'latitude': 51.957963, 'longitude': 0.025416}}
# {'BusinessName': 'Nuthampstead Shooting Ground',
#  'RatingValue': 4,
#  '_id': ObjectId('669ca9eb54452054d92b4ec1'),
#  'geocode': {'latitude': 51.994776, 'longitude': 0.054535}}
# {'BusinessName': 'The Barn At Alswick',
#  'RatingValue': None,
#  '_id': ObjectId('669ca9eb54452054d92b4ec3'),
#  'geocode': {'latitude': 51.947799, 'longitude': 0.001967}}
# {'BusinessName': 'La Vita',
#  'RatingValue': 4,
#  '_id': ObjectId('669ca9eb54452054d92b4ed0'),
#  'geocode': {'latitude': 52.0044032, 'longitude': 0.0159242}}
# {'BusinessName': 'Penang Flavours',
#  'RatingValue': None,
#  '_id': ObjectId('669ca9f6b8bce198c5a8c2a1'),
#  'geocode': {'latitude': 51.490142, 'longitude': 0.08384}}
